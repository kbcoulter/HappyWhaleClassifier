# %% [markdown]
# # Image Classification ML Assignment
#
# The goal of this assignment is to learn fundamentals of machine learning and image analysis. You will analyze images from Happy Whale, an organization that tracks whales globally, and modify a classifier for these images.
#
# Part 1: Walk through (Due Feb 27)
# - In class, we will walk through the provided code
# - This script has several functions that are written for you. For part 1, please do NOT modify any code unless it specifies to change it.
# - Answer the questions as you go through the code
#
# Part 2: Make modifications (Due Feb 27)
# - Change model parameters or other model aspects at least 3 times
# - Describe what happened when you made these changes
#
# Part 3: Create a team, get inspired and try a new approach to your model (Due March 6)
# - Have a group meeting and record your meeting with audio or video (you can record with zoom!)
#     - Start by discussing part 2 of the assignment:
#         - What approaches you each took to change the ML model in part 2
#         - What are similarities and differences between your approaches
#         - What types of changes improved model performance
#         - What types of changes made model performance worse
#         - Based on the whole group's work, what would y'all want to do next in terms of model optimization?
#     - Next, look at code and approaches from the [Happy Whales competition leaderboard](https://www.kaggle.com/competitions/happy-whale-and-dolphin/leaderboard).
#         - Is there any strategy that someone used that you could implement?
#             - Ex: learning rate value, # epochs, transformation strategy, or more complex changes to the models
#         - Are there strategies that you are interested in learning about?
#     - Lastly, make a plan for 1 more round of model optimization
#         - Assign each member something to attempt for training the model. Use your cumulative experience to decide the most important things to test.
#         - Group members can make as small as changing the value for a parameter or as big as changing the model.
# - Have each member complete their test
# - Share results with each other
# - Write a 1-3 paragraph summary on your group's attempts and recommendations moving forward
# - For Part 3: Turn in the audio/video recording of the group meeting, each member's code (uploaded to their original git repo), and the team's 1-3 paragraph summary over canvas.

# %% [markdown]
# ### Your choices on data
# You can chose between 3 datasets for this assignment. This jupyter notebook is set up using the Species dataset. If you change the dataset, you will need to change the number of classes parameter for the model.
# - Species = you will classify images by species (gray, killer, beluga, humpback, false killer, and common dolphin)
#   - File path: /projects/bgmp/shared/Bi625/ML_Assignment/Datasets/Whale_species/species
# - Species_all = you will classify images by species (minke, gray, killer, beluga, humpback, false killer, and bottlenose and common dolphin). There are a high number of images for bottlenose dolphins and minke whales which leads to this dataset being quite large. Due to the size of the dataset, it has a longer training time than the "Species" dataset.
#   - File path: /projects/bgmp/shared/Bi625/ML_Assignment/Datasets/Whale_species/species_all
#   - Num classes: 8
# - Individuals = you will classify images by individuals. This is a much more challenging classification task because you have different individuals from different species. However, this was the original goal of the Happy Whale competition, so try challenging yourself to this important task!
#   - File path: /projects/bgmp/shared/Bi625/ML_Assignment/Datasets/Whale_species/individuals
#   - Num classes: 110
#
# You are NOT graded by the success of your model, so you are free to train the model on whichever dataset is more interesting to you. However, **everyone on your team for part 3 should be using the same dataset**.

# %% [markdown]
# ### Part 1

# %%
## Importing packages - Please DO NOT alter this box ##
import torch
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
from torch.nn import functional as F
import torch.optim as optim
from torch.utils.data.sampler import WeightedRandomSampler
torch.manual_seed(0)

from captum.attr import IntegratedGradients
from captum.attr import DeepLift
from captum.attr import NoiseTunnel
from captum.attr import visualization as viz

import torchvision
from torchvision import datasets, transforms
from torch.utils.tensorboard import SummaryWriter
writer = SummaryWriter()

import os
import imageio
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
from tqdm import tqdm
from scipy.ndimage import binary_erosion
import pandas as pd
from sklearn.metrics import confusion_matrix
import seaborn as sns

import wandb #comment this out if you are not using weights and biases
import random #comment this out if you are not using weights and biases


# Set device to cuda if it's available otherwise default to "cpu"
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# ### Loading in the dataset
#
# By default, this will load in the species dataset, this is the smallest dataset (i.e., it will be relatively fast to train) and has a simple goal (i.e., you will be able to create an accurate model). If you want a challenge, I highly encourage you to try the Species_all (a dataset with 2 additional species) or the individual dataset (a dataset where whales are characterized by individual rather than species).

# %%
images = "/projects/bgmp/shared/Bi625/ML_Assignment/Datasets/Whale_species/species"

# %%
# We must turn our images into tensors, resize, and normalize them 
# We can also add additional transformations to images 
transform = transforms.Compose([transforms.ToTensor(), 
                                #We will start with a model called Resnet18 that is optimized for 224x224 images
                                #It is set to a very SMALL size initially so the model will train fast in class
                                transforms.Resize([32,32]),
                                transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]) # Normalize the data, these are the values that ResNet suggests based on their training data (natural scences)
                               ])
all_images = datasets.ImageFolder(images, transform)
print(all_images)
# Out:
# Dataset ImageFolder
#     Number of datapoints: 2794
#     Root location: /projects/bgmp/shared/Bi625/ML_Assignment/Datasets/Whale_species/species
#     StandardTransform
# Transform: Compose(
#                ToTensor()
#                Resize(size=[32, 32], interpolation=bilinear, max_size=None, antialias=True)
#                Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#            )

# %% [markdown]
# <font color='magenta'>What is the purpose(s) of transforming image data? (2 pts)

# %% [markdown]
# The purpose of transforming our data is to improve the quality of image data for improved model performance by removing noise, adjusting brightness, correcting distortions, and more. Above, we are resizing the images to be small for training speed, and normalizing the image per ResNet suggestions.

# %% [markdown]
# <font color='green'>The below code completes the image transformations as coded in the above box.

# %%
all_images = datasets.ImageFolder(images, transform )
print(len(all_images))
print(all_images)
# Out:
# 2794
# Dataset ImageFolder
#     Number of datapoints: 2794
#     Root location: /projects/bgmp/shared/Bi625/ML_Assignment/Datasets/Whale_species/species
#     StandardTransform
# Transform: Compose(
#                ToTensor()
#                Resize(size=[32, 32], interpolation=bilinear, max_size=None, antialias=True)
#                Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#            )

# %% [markdown]
# Our classification labels will be converted to indices, we can determine which indices is which label using the below code

# %%
print(all_images.class_to_idx)
# Out:
# {'beluga': 0, 'common_dolphin': 1, 'false_killer_whale': 2, 'fin_whale': 3, 'gray_whale': 4, 'humpback_whale': 5}

# %% [markdown]
# <font color='green'>The below function is used to randomly select dataset images to evaluate how the transformations altered the images.

# %%
def show_random_dataset_image(dataset):
    idx = np.random.randint(0, len(dataset))    # take a random sample
    img, mask = dataset[idx]                    # get the image and the nuclei masks
    f, axarr = plt.subplots(1, 2)               # make two plots on one figure
    axarr[0].imshow(img[0], cmap="viridis")                     # show the image, cmap is the color map that the image is being shown in
    #axarr[1].imshow(mask[0])                    # show the masks
    _ = [ax.axis('off') for ax in axarr]        # remove the axes
    print('Image size is %s' % {img[0].shape})
    print(img.shape)
    plt.show()

# %%
show_random_dataset_image(all_images)
# Out:
# Image size is {torch.Size([32, 32])}
# torch.Size([3, 32, 32])

# %% [markdown]
# <font color='magenta'>What is the difference between image size and torch image size? (2 pts)

# %% [markdown]
# Image size is saved as width by height while torch image size is saved as channel by height by width. Torch images also sometimes (but not in our case) include batch, making it batch by channel by height by width.

# %% [markdown]
# <font color='magenta'>Add a new transformation to the training data. After your first run of this model during class time, resize the image to 224x224 pixels. (2 pts)

# %%
## ADD YOUR TRANSFORMATION HERE
transform = transforms.Compose([
            transforms.Resize([224,224]), # Resize the image as our model is optimized for 224x224 pixels
            transforms.ToTensor(),
            transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])]) # Normalize the data, these are the values that ResNet suggests based on their training data (natural scences))

all_images = datasets.ImageFolder(images, transform )
show_random_dataset_image(all_images)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 ## ADD YOUR TRANSFORMATION HERE
# ----> 2 transform = transforms.Compose([
#       3             transforms.Resize([224,224]), # Resize the image as our model is optimized for 224x224 pixels
#       4             transforms.ToTensor(),
#       5             transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])]) # Normalize the data, these are the values that ResNet suggests based on their training data (natural scences))
#       7 all_images = datasets.ImageFolder(images, transform )
#       8 show_random_dataset_image(all_images)
#
# NameError: name 'transforms' is not defined

# %% [markdown]
# <font color='magenta'>How did your transformation impact the images? (1 pt)

# %% [markdown]
# These transformations resulted in sharper, higher resolution, de-noised images with normalized color scales.

# %% [markdown]
# ### Creating datasets used in training and testing
#
# After loading in the data, we separate the data into training, validation, and testing datasets. The training data is inputted into the model during the training phase, and the model's predictions from this data is used to modulate the weights of the model. The validation data is used while the model trains, but the model is in a evaluation rather than training mode. The validation data gives us a real time view on how accurately the model is predicting our labels. The testing data is used after the model has completed training and tells us how successful our model will be with a novel dataset.
#
# Once creating these 3 datasets, we prepare dataloaders which are used to load the images into our models. These images are loaded in batches into the model (a parameter called batch size). Because our dataset is imbalanced, we use a weighted random sampler to select images for our batches in the dataloader. Therefore to create our dataloader, we start by creating a function to get weights, calculating weights, initiating our weighted random sampler, and then creating our dataloaders.

# %% [markdown]
# <font color='green'>The below code eastablishes the data split between training, validation, and testing.

# %%
train_size = int(0.7 * len(all_images))
val_size = int(0.15 * len(all_images))
test_size = len(all_images) - (train_size + val_size)
print(train_size, val_size, test_size)
assert train_size + val_size + test_size == len(all_images)
# Out:
# 1955 419 420

# %%
train_set, val_set, test_set = torch.utils.data.random_split(all_images, [train_size, val_size, test_size])

# %% [markdown]
# <font color='green'>The below function is used to get weights for the image classes.

# %%
def _get_weights(subset,full_dataset):
    ys = np.array([y for _, y in subset])
    counts = np.bincount(ys)
    label_weights = 1.0 / counts
    weights = label_weights[ys]

    print("Number of images per class:")
    for c, n, w in zip(full_dataset.classes, counts, label_weights):
        print(f"\t{c}:\tn={n}\tweight={w}")
        
    return weights

# %%
train_weights = _get_weights(train_set,all_images)
train_sampler = WeightedRandomSampler(train_weights, len(train_weights))
# Out:
# Number of images per class:
# 	beluga:	n=465	weight=0.002150537634408602
# 	common_dolphin:	n=50	weight=0.02
# 	false_killer_whale:	n=716	weight=0.0013966480446927375
# 	fin_whale:	n=116	weight=0.008620689655172414
# 	gray_whale:	n=44	weight=0.022727272727272728
# 	humpback_whale:	n=564	weight=0.0017730496453900709

# %% [markdown]
# <font color='magenta'>What is the impact of the class weight on how data is loaded into the model? What does it mean if a class has a low vs high weight? (2 pts)

# %% [markdown]
# <details>
#   <summary>Hint</summary>
#
# Check out this resource: https://towardsdatascience.com/demystifying-pytorchs-weightedrandomsampler-by-example-a68aceccb452

# %% [markdown]
# Class weight changes how data is loaded in by changing the liklihood that a given sample is chosen. A higher weight means that a class is chosen more frequently while a low weight means that a class is chosen less frequently.

# %%
train_loader = DataLoader(train_set, batch_size=48, drop_last=True, sampler=train_sampler)
val_loader = DataLoader(val_set, batch_size=48, drop_last=True, shuffle=True)
test_loader = DataLoader(test_set, batch_size=48, drop_last=True, shuffle=True)

# %% [markdown]
# ### Picking hyperparameters
#
# We can set a few hyperparameters that we decide and can tune. These include:
#
# - Learning rate = how much to update our model's parameters at each batch/epoch
# - batch size = the number of data samples to pass through the network before updating it
#     - If you change the batchsize below, make sure you ALSO change it in the commands above for the DataLoader
# - Number of epochs = # of times to iterate over the dataset in model training

# %%
learning_rate=1e-3
batchsize=48
epochs=5

# %% [markdown]
# <font color='magenta'>How would model training be impacted if we decreased our learning rate? What about if we increased it? (2 pts)

# %% [markdown]
# The learning rate essentially dictates how agressively the model updates in training. So decreasing the learning rate would result in less substantial updates per batch in training, while increasing the learning rate would result in larger updates per batch in training.

# %% [markdown]
# ### Training our model
#
# For part 1, we are going to use the model ResNet18. This is a published model for imaging data. Resnet18 is built from 4 residual blocks with two convolutional layers (Conv2d). Each convolutional layer is followed by a batch normalization step (BatchNorm2D) and a ReLU activation layer (ReLU). There is also a shortcut connection which adds input to output and allows the network to learn residual mapping.
#
# I provided the complete code for the ResNet18 model. In the future, if you want to use resnet18, you can load it simply by running `resnet18_model = torchvision.models.resnet18(weights = False, progress  = True, num_classes=XXX)`. We will look at the full code for the model so you can see how this model was created.

# %% [markdown]
# <font color='green'>The below code builds the residual blocks that ResNet18 uses in the model.

# %%
## First, we create the basic block that will be used in our residual net
class BasicBlock(nn.Module):
    # Initializing method for the basic block (It's OOP!)
    def __init__(self, in_channels, out_channels, stride=1):
        super(BasicBlock, self).__init__()
        ## Conv1: convolution layer, batch normalization, ReLU activation
        self.conv1 = nn.Conv2d(in_channels, out_channels, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(out_channels)
        self.relu = nn.ReLU(inplace=True)

        ## Conv2: convolution layer, batch normalization
        self.conv2 = nn.Conv2d(out_channels, out_channels, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(out_channels)

        ## Shortcut connection: adds input to output
        self.shortcut = nn.Sequential()
        if stride != 1 or in_channels != out_channels:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_channels, out_channels, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(out_channels)
            )

    # The forward method calls on each layer
    def forward(self, x):
        ## Conv1: convolution layer, batch normalization, ReLU activation
        out = self.conv1(x) 
        out = self.bn1(out)
        out = self.relu(out)
        ## Conv2: convolution layer, batch normalization
        out = self.conv2(out)
        out = self.bn2(out)
        ## Shortcut connection
        out += self.shortcut(x)
        ## Final activation
        out = self.relu(out)
        return out

# %% [markdown]
# <font color='green'>The below code builds and initializes the ResNet18 model.

# %%
## Next, we put together these building blocks and create our residual net
class ResNet18(nn.Module):
    # specify the number of classes that we are predicting
    def __init__(self, num_classes=6):
        super(ResNet18, self).__init__()
        # In channels = Num pixels in H + Num pixels in W
        self.in_channels = 64
        
        # First convolution set (convolution, batch norm, relu)
        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)
        self.relu = nn.ReLU(inplace=True)

        # Our building blocks
        # The numbers correspond to the matrix shape
        ### We increase the number of filters/channels (i.e., the first number) as we go
        self.layer1 = self._make_layer(BasicBlock, 64, 2, stride=1)
        self.layer2 = self._make_layer(BasicBlock, 128, 2, stride=2)
        self.layer3 = self._make_layer(BasicBlock, 256, 2, stride=2)
        self.layer4 = self._make_layer(BasicBlock, 512, 2, stride=2)

        # Average pooling 
        self.avgpool = nn.AdaptiveAvgPool2d((1, 1))

        # Final layer that makes the classification
        self.fc = nn.Linear(512, num_classes)

    def _make_layer(self, block, out_channels, num_blocks, stride):
        strides = [stride] + [1]*(num_blocks-1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_channels, out_channels, stride))
            self.in_channels = out_channels
        return nn.Sequential(*layers)

    def forward(self, x):
        # First convolution set (convolution, batch norm, relu)
        out = self.conv1(x)
        out = self.bn1(out)
        out = self.relu(out)
        # Our 4 building blocks
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        
        out = self.avgpool(out)
        out = out.view(out.size(0), -1)
        # Final layer that makes the classification
        out = self.fc(out)
        return out

## Getting our model and transferring it to the GPU
model = ResNet18().to(device)
print(model)
# Out:
# ResNet18(
#   (conv1): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=6, bias=True)
# )

# %% [markdown]
# <font color='green'>The below code eastablishes the loss function and optimizer used in training the model.

# %%
#define loss function & optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# %% [markdown]
# <font color='green'>The below functions are used to train, evaluate, and test the Machine Learning model.

# %%
"""
wandb.init(
    project="BGMP_HappyWhale",
    name="Hope-HappyWhale-SpeciesDataset-hyperparameters", ### Update with your name!
    config={"learning rate":0.001,
        "architecture": "CNN",
        "dataset": "Species",
        "epochs":5}
)
"""

num_epochs = epochs
train_losses, train_acc_list, val_losses, val_acc_list = [], [], [],[]

for epoch in range(num_epochs):
    # Setting model to "training mode"
    model.train()
    running_loss = 0.0
    correct, total = 0, 0
    batch=0

    # For each batch of data within the loader
    for inputs, labels in train_loader:
        # Send our input images and their labels to the GPU
        inputs, labels = inputs.to(device), labels.to(device)
        # Zero the gradients
        optimizer.zero_grad()
        # Inputting our training images into the model
        # and Predicting the image classification label
        outputs = model(inputs)
        # Figuring out the loss from our predictions
        loss = criterion(outputs, labels)
        # Compute gradients (aka backward pass)
        loss.backward()
        # Update model parameters
        optimizer.step()

        # Adding the loss to our running sum
        # Loss is calculated for each batch within an epoch
        running_loss += loss.item() * inputs.size(0)
        _, predicted = outputs.max(1)
        total += labels.size(0)
        correct += predicted.eq(labels).sum().item()
        batch+=1
        print(f'Epoch [{epoch+1}/{num_epochs}] | Batch #{batch} | Batch Accuracy {(correct/total)*100:.2f}%')


    # Getting metrics for our training pass 
    train_loss = running_loss / len(train_loader.dataset)
    train_acc = 100. * correct / total
    train_losses.append(train_loss)
    train_acc_list.append(train_acc)
    
    # Switching our model to "evaluation mode"
    model.eval()
    running_loss = 0.0
    correct, total = 0, 0
    # Disable gradient calculation b/c we are evalulating the model
    with torch.no_grad():
        # Load in batches of our validation data
        for inputs, labels in val_loader:
            # Send test images and labels to the GPU
            inputs, labels = inputs.to(device), labels.to(device)
            # Predict the image classification label
            outputs = model(inputs)
            _, predicted = outputs.max(1)
            total += labels.size(0)
            # Figuring out how many predicted labels = true labels
            correct += predicted.eq(labels).sum().item()

            # Figuring out the loss from our predictions
            loss = criterion(outputs, labels)
            # Adding the loss to our running sum
            # Loss is calculated for each batch within an epoch
            running_loss += loss.item() * inputs.size(0)
    # Getting our accuracy from our test data
    val_acc = 100. * correct / total
    val_acc_list.append(val_acc)
    # Getting the loss from our test data
    val_loss = running_loss / len(val_loader.dataset)
    val_losses.append(val_loss)
    
    print(f'Epoch [{epoch+1}/{num_epochs}] Train Loss: {train_loss:.4f} | Train Acc: {train_acc:.2f}% | Val Acc: {val_acc:.2f}% | Val Loss: {val_loss:.2f}%')

    # log metrics to wandb
    #wandb.log({"validation_accuracy": val_acc, "validation_loss": val_loss, "train_loss":train_loss})

#wandb.finish()



"""
Epoch [1/5] Train Loss: 1.3112 | Train Acc: 52.92% | Val Acc: 43.23% | Val Loss: 1.52%
Epoch [2/5] Train Loss: 0.9510 | Train Acc: 64.64% | Val Acc: 46.88% | Val Loss: 2.52%
Epoch [3/5] Train Loss: 0.9169 | Train Acc: 67.55% | Val Acc: 45.57% | Val Loss: 2.90%
Epoch [4/5] Train Loss: 0.8740 | Train Acc: 67.45% | Val Acc: 64.06% | Val Loss: 0.95%
Epoch [5/5] Train Loss: 0.8008 | Train Acc: 70.78% | Val Acc: 66.15% | Val Loss: 0.84%
"""
# Out:
# Epoch [1/5] | Batch #1 | Batch Accuracy 18.75%
# Epoch [1/5] | Batch #2 | Batch Accuracy 16.67%
# Epoch [1/5] | Batch #3 | Batch Accuracy 21.53%
# Epoch [1/5] | Batch #4 | Batch Accuracy 20.83%
# Epoch [1/5] | Batch #5 | Batch Accuracy 25.00%
# Epoch [1/5] | Batch #6 | Batch Accuracy 26.39%
# Epoch [1/5] | Batch #7 | Batch Accuracy 27.08%
# Epoch [1/5] | Batch #8 | Batch Accuracy 29.43%
# Epoch [1/5] | Batch #9 | Batch Accuracy 31.48%
# Epoch [1/5] | Batch #10 | Batch Accuracy 33.75%
# Epoch [1/5] | Batch #11 | Batch Accuracy 35.80%
# Epoch [1/5] | Batch #12 | Batch Accuracy 38.02%
# Epoch [1/5] | Batch #13 | Batch Accuracy 38.46%
# Epoch [1/5] | Batch #14 | Batch Accuracy 39.14%
# Epoch [1/5] | Batch #15 | Batch Accuracy 40.42%
# Epoch [1/5] | Batch #16 | Batch Accuracy 41.41%
# Epoch [1/5] | Batch #17 | Batch Accuracy 41.67%
# Epoch [1/5] | Batch #18 | Batch Accuracy 41.44%
# Epoch [1/5] | Batch #19 | Batch Accuracy 42.54%
# Epoch [1/5] | Batch #20 | Batch Accuracy 42.92%
# Epoch [1/5] | Batch #21 | Batch Accuracy 42.86%
# Epoch [1/5] | Batch #22 | Batch Accuracy 43.28%
# Epoch [1/5] | Batch #23 | Batch Accuracy 44.38%
# Epoch [1/5] | Batch #24 | Batch Accuracy 45.66%
# Epoch [1/5] | Batch #25 | Batch Accuracy 46.00%
# Epoch [1/5] | Batch #26 | Batch Accuracy 46.55%
# Epoch [1/5] | Batch #27 | Batch Accuracy 47.15%
# Epoch [1/5] | Batch #28 | Batch Accuracy 47.32%
# Epoch [1/5] | Batch #29 | Batch Accuracy 47.77%
# Epoch [1/5] | Batch #30 | Batch Accuracy 48.61%
# Epoch [1/5] | Batch #31 | Batch Accuracy 49.06%
# Epoch [1/5] | Batch #32 | Batch Accuracy 49.48%
# Epoch [1/5] | Batch #33 | Batch Accuracy 50.00%
# Epoch [1/5] | Batch #34 | Batch Accuracy 50.55%
# Epoch [1/5] | Batch #35 | Batch Accuracy 50.89%
# Epoch [1/5] | Batch #36 | Batch Accuracy 51.39%
# Epoch [1/5] | Batch #37 | Batch Accuracy 51.86%
# Epoch [1/5] | Batch #38 | Batch Accuracy 52.47%
# Epoch [1/5] | Batch #39 | Batch Accuracy 52.62%
# Epoch [1/5] | Batch #40 | Batch Accuracy 52.92%
# Epoch [1/5] Train Loss: 1.3112 | Train Acc: 52.92% | Val Acc: 43.23% | Val Loss: 1.52%
# Epoch [2/5] | Batch #1 | Batch Accuracy 62.50%
# Epoch [2/5] | Batch #2 | Batch Accuracy 56.25%
# Epoch [2/5] | Batch #3 | Batch Accuracy 56.94%
# Epoch [2/5] | Batch #4 | Batch Accuracy 57.29%
# Epoch [2/5] | Batch #5 | Batch Accuracy 57.92%
# Epoch [2/5] | Batch #6 | Batch Accuracy 59.03%
# Epoch [2/5] | Batch #7 | Batch Accuracy 59.52%
# Epoch [2/5] | Batch #8 | Batch Accuracy 58.07%
# Epoch [2/5] | Batch #9 | Batch Accuracy 57.64%
# Epoch [2/5] | Batch #10 | Batch Accuracy 57.50%
# Epoch [2/5] | Batch #11 | Batch Accuracy 57.58%
# Epoch [2/5] | Batch #12 | Batch Accuracy 57.99%
# Epoch [2/5] | Batch #13 | Batch Accuracy 58.17%
# Epoch [2/5] | Batch #14 | Batch Accuracy 59.08%
# Epoch [2/5] | Batch #15 | Batch Accuracy 59.17%
# Epoch [2/5] | Batch #16 | Batch Accuracy 59.51%
# Epoch [2/5] | Batch #17 | Batch Accuracy 60.42%
# Epoch [2/5] | Batch #18 | Batch Accuracy 60.88%
# Epoch [2/5] | Batch #19 | Batch Accuracy 60.75%
# Epoch [2/5] | Batch #20 | Batch Accuracy 60.62%
# Epoch [2/5] | Batch #21 | Batch Accuracy 61.41%
# Epoch [2/5] | Batch #22 | Batch Accuracy 61.27%
# Epoch [2/5] | Batch #23 | Batch Accuracy 61.14%
# Epoch [2/5] | Batch #24 | Batch Accuracy 61.20%
# Epoch [2/5] | Batch #25 | Batch Accuracy 61.42%
# Epoch [2/5] | Batch #26 | Batch Accuracy 61.70%
# Epoch [2/5] | Batch #27 | Batch Accuracy 61.96%
# Epoch [2/5] | Batch #28 | Batch Accuracy 61.83%
# Epoch [2/5] | Batch #29 | Batch Accuracy 62.50%
# Epoch [2/5] | Batch #30 | Batch Accuracy 62.36%
# Epoch [2/5] | Batch #31 | Batch Accuracy 62.37%
# Epoch [2/5] | Batch #32 | Batch Accuracy 62.70%
# Epoch [2/5] | Batch #33 | Batch Accuracy 63.07%
# Epoch [2/5] | Batch #34 | Batch Accuracy 63.11%
# Epoch [2/5] | Batch #35 | Batch Accuracy 62.98%
# Epoch [2/5] | Batch #36 | Batch Accuracy 63.37%
# Epoch [2/5] | Batch #37 | Batch Accuracy 63.68%
# Epoch [2/5] | Batch #38 | Batch Accuracy 63.98%
# Epoch [2/5] | Batch #39 | Batch Accuracy 64.10%
# Epoch [2/5] | Batch #40 | Batch Accuracy 64.64%
# Epoch [2/5] Train Loss: 0.9510 | Train Acc: 64.64% | Val Acc: 46.88% | Val Loss: 2.52%
# Epoch [3/5] | Batch #1 | Batch Accuracy 66.67%
# Epoch [3/5] | Batch #2 | Batch Accuracy 70.83%
# Epoch [3/5] | Batch #3 | Batch Accuracy 70.14%
# Epoch [3/5] | Batch #4 | Batch Accuracy 68.75%
# Epoch [3/5] | Batch #5 | Batch Accuracy 68.33%
# Epoch [3/5] | Batch #6 | Batch Accuracy 68.40%
# Epoch [3/5] | Batch #7 | Batch Accuracy 69.94%
# Epoch [3/5] | Batch #8 | Batch Accuracy 69.53%
# Epoch [3/5] | Batch #9 | Batch Accuracy 68.98%
# Epoch [3/5] | Batch #10 | Batch Accuracy 69.58%
# Epoch [3/5] | Batch #11 | Batch Accuracy 70.27%
# Epoch [3/5] | Batch #12 | Batch Accuracy 69.27%
# Epoch [3/5] | Batch #13 | Batch Accuracy 68.75%
# Epoch [3/5] | Batch #14 | Batch Accuracy 69.35%
# Epoch [3/5] | Batch #15 | Batch Accuracy 69.03%
# Epoch [3/5] | Batch #16 | Batch Accuracy 68.62%
# Epoch [3/5] | Batch #17 | Batch Accuracy 68.26%
# Epoch [3/5] | Batch #18 | Batch Accuracy 68.75%
# Epoch [3/5] | Batch #19 | Batch Accuracy 69.08%
# Epoch [3/5] | Batch #20 | Batch Accuracy 68.85%
# Epoch [3/5] | Batch #21 | Batch Accuracy 68.35%
# Epoch [3/5] | Batch #22 | Batch Accuracy 68.47%
# Epoch [3/5] | Batch #23 | Batch Accuracy 67.57%
# Epoch [3/5] | Batch #24 | Batch Accuracy 67.01%
# Epoch [3/5] | Batch #25 | Batch Accuracy 66.83%
# Epoch [3/5] | Batch #26 | Batch Accuracy 66.67%
# Epoch [3/5] | Batch #27 | Batch Accuracy 66.82%
# Epoch [3/5] | Batch #28 | Batch Accuracy 66.74%
# Epoch [3/5] | Batch #29 | Batch Accuracy 66.67%
# Epoch [3/5] | Batch #30 | Batch Accuracy 66.67%
# Epoch [3/5] | Batch #31 | Batch Accuracy 66.87%
# Epoch [3/5] | Batch #32 | Batch Accuracy 67.19%
# Epoch [3/5] | Batch #33 | Batch Accuracy 66.67%
# Epoch [3/5] | Batch #34 | Batch Accuracy 66.91%
# Epoch [3/5] | Batch #35 | Batch Accuracy 67.14%
# Epoch [3/5] | Batch #36 | Batch Accuracy 67.19%
# Epoch [3/5] | Batch #37 | Batch Accuracy 67.17%
# Epoch [3/5] | Batch #38 | Batch Accuracy 67.43%
# Epoch [3/5] | Batch #39 | Batch Accuracy 67.52%
# Epoch [3/5] | Batch #40 | Batch Accuracy 67.55%
# Epoch [3/5] Train Loss: 0.9169 | Train Acc: 67.55% | Val Acc: 45.57% | Val Loss: 2.90%
# Epoch [4/5] | Batch #1 | Batch Accuracy 62.50%
# Epoch [4/5] | Batch #2 | Batch Accuracy 65.62%
# Epoch [4/5] | Batch #3 | Batch Accuracy 65.97%
# Epoch [4/5] | Batch #4 | Batch Accuracy 63.02%
# Epoch [4/5] | Batch #5 | Batch Accuracy 64.58%
# Epoch [4/5] | Batch #6 | Batch Accuracy 68.40%
# Epoch [4/5] | Batch #7 | Batch Accuracy 67.86%
# Epoch [4/5] | Batch #8 | Batch Accuracy 68.23%
# Epoch [4/5] | Batch #9 | Batch Accuracy 68.75%
# Epoch [4/5] | Batch #10 | Batch Accuracy 67.08%
# Epoch [4/5] | Batch #11 | Batch Accuracy 66.29%
# Epoch [4/5] | Batch #12 | Batch Accuracy 66.67%
# Epoch [4/5] | Batch #13 | Batch Accuracy 66.19%
# Epoch [4/5] | Batch #14 | Batch Accuracy 66.37%
# Epoch [4/5] | Batch #15 | Batch Accuracy 65.69%
# Epoch [4/5] | Batch #16 | Batch Accuracy 65.89%
# Epoch [4/5] | Batch #17 | Batch Accuracy 66.42%
# Epoch [4/5] | Batch #18 | Batch Accuracy 66.55%
# Epoch [4/5] | Batch #19 | Batch Accuracy 66.78%
# Epoch [4/5] | Batch #20 | Batch Accuracy 66.46%
# Epoch [4/5] | Batch #21 | Batch Accuracy 67.26%
# Epoch [4/5] | Batch #22 | Batch Accuracy 67.42%
# Epoch [4/5] | Batch #23 | Batch Accuracy 68.21%
# Epoch [4/5] | Batch #24 | Batch Accuracy 67.71%
# Epoch [4/5] | Batch #25 | Batch Accuracy 67.67%
# Epoch [4/5] | Batch #26 | Batch Accuracy 67.31%
# Epoch [4/5] | Batch #27 | Batch Accuracy 67.52%
# Epoch [4/5] | Batch #28 | Batch Accuracy 67.19%
# Epoch [4/5] | Batch #29 | Batch Accuracy 67.10%
# Epoch [4/5] | Batch #30 | Batch Accuracy 67.15%
# Epoch [4/5] | Batch #31 | Batch Accuracy 67.00%
# Epoch [4/5] | Batch #32 | Batch Accuracy 66.86%
# Epoch [4/5] | Batch #33 | Batch Accuracy 66.98%
# Epoch [4/5] | Batch #34 | Batch Accuracy 66.67%
# Epoch [4/5] | Batch #35 | Batch Accuracy 66.67%
# Epoch [4/5] | Batch #36 | Batch Accuracy 66.67%
# Epoch [4/5] | Batch #37 | Batch Accuracy 66.61%
# Epoch [4/5] | Batch #38 | Batch Accuracy 66.72%
# Epoch [4/5] | Batch #39 | Batch Accuracy 67.04%
# Epoch [4/5] | Batch #40 | Batch Accuracy 67.45%
# Epoch [4/5] Train Loss: 0.8740 | Train Acc: 67.45% | Val Acc: 64.06% | Val Loss: 0.95%
# Epoch [5/5] | Batch #1 | Batch Accuracy 64.58%
# Epoch [5/5] | Batch #2 | Batch Accuracy 69.79%
# Epoch [5/5] | Batch #3 | Batch Accuracy 66.67%
# Epoch [5/5] | Batch #4 | Batch Accuracy 67.19%
# Epoch [5/5] | Batch #5 | Batch Accuracy 67.08%
# Epoch [5/5] | Batch #6 | Batch Accuracy 68.40%
# Epoch [5/5] | Batch #7 | Batch Accuracy 68.45%
# Epoch [5/5] | Batch #8 | Batch Accuracy 69.79%
# Epoch [5/5] | Batch #9 | Batch Accuracy 70.83%
# Epoch [5/5] | Batch #10 | Batch Accuracy 71.25%
# Epoch [5/5] | Batch #11 | Batch Accuracy 71.40%
# Epoch [5/5] | Batch #12 | Batch Accuracy 71.88%
# Epoch [5/5] | Batch #13 | Batch Accuracy 71.47%
# Epoch [5/5] | Batch #14 | Batch Accuracy 71.28%
# Epoch [5/5] | Batch #15 | Batch Accuracy 71.39%
# Epoch [5/5] | Batch #16 | Batch Accuracy 70.44%
# Epoch [5/5] | Batch #17 | Batch Accuracy 69.85%
# Epoch [5/5] | Batch #18 | Batch Accuracy 69.91%
# Epoch [5/5] | Batch #19 | Batch Accuracy 70.18%
# Epoch [5/5] | Batch #20 | Batch Accuracy 70.21%
# Epoch [5/5] | Batch #21 | Batch Accuracy 69.94%
# Epoch [5/5] | Batch #22 | Batch Accuracy 70.55%
# Epoch [5/5] | Batch #23 | Batch Accuracy 70.38%
# Epoch [5/5] | Batch #24 | Batch Accuracy 70.83%
# Epoch [5/5] | Batch #25 | Batch Accuracy 70.75%
# Epoch [5/5] | Batch #26 | Batch Accuracy 70.43%
# Epoch [5/5] | Batch #27 | Batch Accuracy 70.29%
# Epoch [5/5] | Batch #28 | Batch Accuracy 70.39%
# Epoch [5/5] | Batch #29 | Batch Accuracy 70.55%
# Epoch [5/5] | Batch #30 | Batch Accuracy 70.07%
# Epoch [5/5] | Batch #31 | Batch Accuracy 70.09%
# Epoch [5/5] | Batch #32 | Batch Accuracy 70.57%
# Epoch [5/5] | Batch #33 | Batch Accuracy 70.58%
# Epoch [5/5] | Batch #34 | Batch Accuracy 70.59%
# Epoch [5/5] | Batch #35 | Batch Accuracy 70.77%
# Epoch [5/5] | Batch #36 | Batch Accuracy 70.83%
# Epoch [5/5] | Batch #37 | Batch Accuracy 70.38%
# Epoch [5/5] | Batch #38 | Batch Accuracy 70.61%
# Epoch [5/5] | Batch #39 | Batch Accuracy 70.51%
# Epoch [5/5] | Batch #40 | Batch Accuracy 70.78%
# Epoch [5/5] Train Loss: 0.8008 | Train Acc: 70.78% | Val Acc: 66.15% | Val Loss: 0.84%

# %% [markdown]
# #### For our class training, run the below model and consider the success of the model training.
#
# <font color='magenta'>What is your starting accuracy and final accuracy? What happened to the model to change the accuracy from epoch 1 to 5? (2 pts)

# %% [markdown]
# The starting training accuracy was 18.75%, increasing to 70.78% training accuracy and 66.15% validation accuracy. With each epoch, the model learned from the training data, adjusted it's weights, and accuracy increased. We see pretty decent validation accuracy compared to training accuracy, suggesting that the model is generalizing well.

# %%
plt.plot(range(num_epochs), val_acc_list, color = "magenta")
plt.xlabel("Epoch number")
plt.ylabel("Valiation accuracy")
plt.show()  

plt.plot(range(num_epochs), val_losses, color = "purple")
plt.xlabel("Epoch number")
plt.ylabel("Valiation loss")
plt.show()

# %% [markdown]
# <font color='green'>After running the model and calculating the overall accuracy, we can examine the data via a confusion matrix which highlights the accuracy by class.

# %%
# predict the test dataset
def predict(model, dataset):
    dataset_prediction = []
    dataset_groundtruth = []
    model = model
    with torch.no_grad():
        for x, y_true in dataset:
            inp = x[None]
            y_pred = model(inp)
            dataset_prediction.append(y_pred.argmax().cpu().numpy())
            dataset_groundtruth.append(y_true)
    
    return np.array(dataset_prediction), np.array(dataset_groundtruth)
            
    # create seaborn heatmap with required labels
    ax=sns.heatmap(cm, annot=annot, fmt='', vmax=30, xticklabels=x_axis_labels, yticklabels=y_axis_labels)
    ax.set_title(title)

# Plot confusion matrix 
# orginally from Runqi Yang; 
# see https://gist.github.com/hitvoice/36cf44689065ca9b927431546381a3f7
def cm_analysis(y_true, y_pred, title, figsize=(10,10)):
    """
    Generate matrix plot of confusion matrix with pretty annotations.
    The plot image is saved to disk.
    args: 
      y_true:    true label of the data, with shape (nsamples,)
      y_pred:    prediction of the data, with shape (nsamples,)
      filename:  filename of figure file to save
      labels:    string array, name the order of class labels in the confusion matrix.
                 use `clf.classes_` if using scikit-learn models.
                 with shape (nclass,).
      ymap:      dict: any -> string, length == nclass.
                 if not None, map the labels & ys to more understandable strings.
                 Caution: original y_true, y_pred and labels must align.
      figsize:   the size of the figure plotted.
    """
    labels = ['Beluga','Common dolphin', 'False killer whale', 'Fin whale', 'Gray whale','Humpback whale']
    cm = confusion_matrix(y_true, y_pred)
    cm_sum = np.sum(cm, axis=1, keepdims=True)
    cm_perc = cm / cm_sum.astype(float) * 100
    annot = np.empty_like(cm).astype(str)
    nrows, ncols = cm.shape
    for i in range(nrows):
        for j in range(ncols):
            c = cm[i, j]
            p = cm_perc[i, j]
            if i == j:
                s = cm_sum[i]
                annot[i, j] = '%.1f%%\n%d/%d' % (p, c, s)
            elif c == 0:
                annot[i, j] = ''
            else:
                annot[i, j] = '%.1f%%\n%d' % (p, c)
    cm = pd.DataFrame(cm, index=labels, columns=labels)
    cm.index.name = 'Actual'
    cm.columns.name = 'Predicted'
    fig, ax = plt.subplots(figsize=figsize)
                              
    x_axis_labels = ['Beluga','Common dolphin', 'False killer whale', 'Fin whale', 'Gray whale','Humpback whale'] # labels for x-axis
    y_axis_labels = ['Beluga','Common dolphin', 'False killer whale', 'Fin whale', 'Gray whale','Humpback whale'] # labels for y-axis
    ax=sns.heatmap(cm, annot=annot, fmt='', vmax=30, xticklabels=x_axis_labels, yticklabels=y_axis_labels, cmap = "viridis")
    ax.set_title(title)

## This plot only contains the test set of data
## The test set of data has not been seen by the model yet
y_pred, y_true = predict(model, test_set)

print(y_true)
cm_analysis(y_true, y_pred, "Confusion matrix")
# Out:
# [5 2 0 2 0 2 5 2 3 0 5 3 5 5 2 5 3 2 5 2 2 5 2 5 5 2 5 2 5 5 0 0 0 4 1 2 2
#  2 5 5 5 3 2 5 2 3 2 5 2 2 0 5 2 3 3 5 2 0 2 2 0 0 0 2 0 0 5 2 0 2 5 5 3 2
#  5 0 0 5 5 2 4 5 5 2 2 2 0 5 5 0 2 0 0 2 0 2 2 5 2 5 5 4 0 0 2 0 2 0 2 0 5
#  0 3 0 0 0 2 2 5 1 2 5 2 3 4 0 5 2 3 0 2 5 0 5 0 0 0 5 5 5 2 5 0 2 5 0 3 2
#  5 2 5 2 2 2 0 2 5 0 0 0 0 5 0 2 5 2 5 2 0 5 2 2 2 5 2 5 5 5 5 5 5 0 3 5 0
#  3 5 5 4 2 5 2 5 2 2 2 2 5 2 2 2 5 2 2 5 2 2 2 0 1 5 5 5 0 2 5 5 0 2 2 2 2
#  2 2 5 2 2 5 1 2 2 2 3 0 0 5 5 4 0 5 2 2 5 0 4 5 4 5 2 0 2 2 5 2 5 0 5 0 2
#  3 2 5 0 0 2 5 0 2 0 2 0 1 0 2 2 5 2 5 2 3 2 5 2 5 5 0 2 2 2 4 5 5 5 5 0 0
#  0 5 2 0 0 5 2 3 2 0 3 5 2 5 0 2 4 2 2 2 2 2 3 0 1 2 0 2 5 2 5 5 2 5 3 0 5
#  3 2 2 5 2 0 3 5 2 0 0 0 1 1 2 5 2 2 2 0 5 2 3 2 2 0 0 2 0 3 2 2 2 2 4 5 2
#  2 0 2 5 0 2 0 2 2 2 0 2 2 5 0 0 0 2 2 2 5 0 2 2 3 2 0 0 0 0 2 2 0 5 0 4 0
#  3 2 5 2 5 2 2 5 5 0 2 2 2]
# /tmp/ipykernel_2972830/2764316866.py:50: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   annot[i, j] = '%.1f%%\n%d/%d' % (p, c, s)

# %% [markdown]
# ### What features did the model use to make decisions?
#
# Based on the confusion matrices and validation loss, it is clear that the model is learning. To determine the features that are involved in decision making, there are a few possible approaches. One options is shown below, integrated gradients.

# %% [markdown]
# #### Understanding feature importance using Integrated Gradients
#
# <font color='green'>Integrated gradients is an attribution method. Attribution methods score the input data based on the prediction that the model makes using scores for each feature. The gradient is the signal that tells the network how much to increase or decrease a certain weight in the network during backpropogation. These gradients are overlaid onto the images to showcase the regions on the images that influence the weights.
#
# Run the below code.

# %%
def visualize_ig(idx, 
                 _train_dataset=train_set, 
                 _test_dataset=test_set):
        
    # Get corresponding input and target tensors:
    input_tensor = _test_dataset[idx][0].unsqueeze(0)
    input_tensor.requires_grad = True
    target = _test_dataset[idx][1]
    
    # We will use the IntegratedGradients algorithm:
    algorithm = IntegratedGradients(model)
    
    # First we clear the gradients from the model:
    model.zero_grad()
    
    # Run attribution:
    attr_ig, delta = algorithm.attribute(input_tensor,
                                          target=target,
                                          baselines=input_tensor * 0,
                                          return_convergence_delta=True
                                        )
    
    # Integrated Gradients:
    attr_ig = np.transpose(attr_ig[0].cpu().detach().numpy(), (1, 2, 0))
    
    # Original image:
    original_image = np.transpose((_test_dataset[idx][0].detach().numpy() * 0.5) + 0.5, (1, 2, 0))
    
    print("Annotated whale species", test_true[idx])
    plt.imshow(original_image)
    
    
    print("Predicted whale species", test_pred[idx])


    # This visualises the attribution of labels to 
    viz.visualize_image_attr(attr_ig, 
                             original_image, 
                             method="blended_heat_map",
                             sign="all",
                             show_colorbar=True, 
                             title="Overlayed Integrated Gradients")

test_pred, test_true = predict(model, test_set)

visualize_ig(0)
visualize_ig(8)
visualize_ig(20)
visualize_ig(32)

# %% [markdown]
# <font color='magenta'>Does the integrated gradient show what types of features the model used to classify the images? Do you notice any potential problems? (2 pts)

# %% [markdown]
# The model generally uses features that are different in color than the background (generally the blue water) and with a hard, defined shape. This would normally be okay, but above, we see background features such as tree lines or mountains being used in prediction. This is a problem, as we are predicting based on non-whale features and backgrounds in these images.

# %% [markdown]
# ## Part 2
#
# Now that you have a sense for how to train a machine learning model, your task is to improve the success of our classification model.
#
# **In three separate training events, make one (or more) modifications to the model training process, re-train the model, and report out your changes and whether they increased model accuracy. Why did you chose your particular change (curiousity, hypothesis, ect.)? Do you have ideas why your modifications were/were not successful?**
#
# Types of changes that you can make include:
# - [Using the pre-trained weights for ResNet18 (transfer learning)](https://docs.pytorch.org/vision/main/models/generated/torchvision.models.resnet18.html)
# - Changing hyperparameters (learning rate, batch size)
# - [Changing transformation approach](https://docs.pytorch.org/vision/0.11/auto_examples/plot_transforms.html#sphx-glr-auto-examples-plot-transforms-py)
# - [Changing the optimizer](https://docs.pytorch.org/docs/stable/optim.html)
# - [Changing the model to a different pre-made model architecture](https://docs.pytorch.org/vision/main/models.html)
# - Modifying the ResNet18 model
# - Coming up with a whole new model!
#
# If you decide to change any lines of code that are not in the below box, please add them to the box (DO NOT MODIFY ANY CODE ABOVE THIS MARKDOWN BOX - IT MAY BREAK PART 1).
#
# If your changes are ambitious, the code may take hours to run. If this is the case, please consider turning this notebook into a python script and running it via sBATCH.
#
# **Please note, you will NOT be graded by the success of your classifiers! It is okay if you are unable to improve the accuracy of the classifier**

# %% [markdown]
# #### Your Model 1 (10 pts)

# %% [markdown]
# <font color='magenta'>Describe your changes to the model training process (either changing something about the model, a hyperparameter, how data was inputted into the model, or another aspect) and why you selected those changes.

# %% [markdown]
# Here, I left most options unchanged and, instead, chose to use the provided resnet18 starting model weights. By using the optimal starting weights, the model will be familiar with features (like edges and textures) generic to image classification, allowing me to focus on finetuning to my own images afterwards. I expect an immediate improvement and to be fine-tuning other parameters specific to whale species classification later.

# %%
batchsize = 48
learning_rate=1e-3
epochs=5

train_loader = DataLoader(train_set, batch_size=batchsize, drop_last=True, sampler=train_sampler)
val_loader = DataLoader(val_set, batch_size=batchsize, drop_last=True, shuffle=True)
test_loader = DataLoader(test_set, batch_size=batchsize, drop_last=True, shuffle=True)

# %%
## Model
from torchvision.models import resnet18, ResNet18_Weights


## Getting our model and transferring it to the GPU
#model = ResNet18()

model = resnet18(weights=ResNet18_Weights.IMAGENET1K_V1, progress  = True).to(device)
nf = model.fc.in_features
model.fc = nn.Linear(nf,6).to(device)

#define loss function & optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# %%
wandb.init(
    project="BGMP_HappyWhale",
    name="Kadens_resnet18_1KV1", ##update this with your name
    config={"learning rate":0.001, # possibly update
        "architecture": "CNN",
        "dataset": "Species",
        "epochs": 5, "batch_size":48}  # possibly update
) 
batch=0
num_epochs = epochs
train_losses, train_acc_list, val_losses, val_acc_list = [], [], [],[]

for epoch in range(num_epochs):
    # Setting model to "training mode"
    model.train()
    running_loss = 0.0
    correct, total = 0, 0

    # For each batch of data within the loader
    for inputs, labels in train_loader:
        # Send our input images and their labels to the GPU
        inputs, labels = inputs.to(device), labels.to(device)
        # Zero the gradients
        optimizer.zero_grad()
        # Inputting our training images into the model
        # and Predicting the image classification label
        outputs = model(inputs)
        # Figuring out the loss from our predictions
        loss = criterion(outputs, labels)
        # Compute gradients (aka backward pass)
        loss.backward()
        # Update model parameters
        optimizer.step()

        # Adding the loss to our running sum
        # Loss is calculated for each batch within an epoch
        running_loss += loss.item() * inputs.size(0)
        _, predicted = outputs.max(1)
        total += labels.size(0)
        correct += predicted.eq(labels).sum().item()
        batch+=1
        print(f'Epoch [{epoch+1}/{num_epochs}] | Batch #{batch} | Batch Accuracy {(correct/total)*100:.2f}%')


    # Getting metrics for our training pass 
    train_loss = running_loss / len(train_loader.dataset)
    train_acc = 100. * correct / total
    train_losses.append(train_loss)
    train_acc_list.append(train_acc)
    
    # Switching our model to "evaluation mode"
    model.eval()
    running_loss = 0.0
    correct, total = 0, 0
    # Disable gradient calculation b/c we are evalulating the model
    with torch.no_grad():
        # Load in batches of our validation data
        for inputs, labels in val_loader:
            # Send test images and labels to the GPU
            inputs, labels = inputs.to(device), labels.to(device)
            # Predict the image classification label
            outputs = model(inputs)
            _, predicted = outputs.max(1)
            total += labels.size(0)
            # Figuring out how many predicted labels = true labels
            correct += predicted.eq(labels).sum().item()

            # Figuring out the loss from our predictions
            loss = criterion(outputs, labels)
            # Adding the loss to our running sum
            # Loss is calculated for each batch within an epoch
            running_loss += loss.item() * inputs.size(0)
    # Getting our accuracy from our test data
    val_acc = 100. * correct / total
    val_acc_list.append(val_acc)
    # Getting the loss from our test data
    val_loss = running_loss / len(val_loader.dataset)
    val_losses.append(val_loss)
    
    print(f'Epoch [{epoch+1}/{num_epochs}] Train Loss: {train_loss:.4f} | Train Acc: {train_acc:.2f}% | Val Acc: {val_acc:.2f}% | Val Loss: {val_loss:.2f}%')

    wandb.log({"validation_accuracy": val_acc, "validation_loss": val_loss, "train_loss":train_loss})

wandb.finish()

"""
Epoch [1/5] Train Loss: 0.3425 | Train Acc: 87.08% | Val Acc: 78.39% | Val Loss: 0.81%
Epoch [2/5] Train Loss: 0.1362 | Train Acc: 94.90% | Val Acc: 88.80% | Val Loss: 0.33%
Epoch [3/5] Train Loss: 0.1030 | Train Acc: 96.35% | Val Acc: 92.19% | Val Loss: 0.20%
Epoch [4/5] Train Loss: 0.0619 | Train Acc: 98.07% | Val Acc: 90.62% | Val Loss: 0.32%
Epoch [5/5] Train Loss: 0.0819 | Train Acc: 97.19% | Val Acc: 91.93% | Val Loss: 0.22%
"""

# %%
plt.plot(range(epochs), val_acc_list, color="magenta")
plt.xlabel("Epoch number")
plt.ylabel("Validation accuracy")
plt.show()

plt.plot(range(epochs), val_losses, color="purple")
plt.xlabel("Epoch number")
plt.ylabel("Validation loss")
plt.show()

y_pred, y_true = predict(model, test_set)
cm_analysis(y_true, y_pred, "Confusion matrix")

# %% [markdown]
# <font color='magenta'>Were your changes successful? Do you have ideas why your changes were successful or not?

# %% [markdown]
# Yes, my changes were very successful. We see a much better accuracy in training and validation at 97.19% and 91.93% respectively, demonstrating better performance and generalization. Because the model does not have to learn image features from scratch, it is better able to adjust to specific whale images in training.

# %% [markdown]
# #### Your Model 2 (10pts)

# %% [markdown]
# <font color='magenta'>Describe your changes to the model training process (either changing something about the model, a hyperparameter, how data was inputted into the model, or another aspect) and why you selected those changes.

# %% [markdown]
# Here, I chose to slightly decrease the learning rate, as our training performance is still notably better than validation, suggesting some slight overfitting. In line with this, I also introduced a weight decay to the optimizer, essentially shrinking the weights as training continues to help prevent overfitting.

# %%
batchsize = 48
learning_rate=1.5e-4
epochs=5

train_loader = DataLoader(train_set, batch_size=batchsize, drop_last=True, sampler=train_sampler)
val_loader = DataLoader(val_set, batch_size=batchsize, drop_last=True, shuffle=True)
test_loader = DataLoader(test_set, batch_size=batchsize, drop_last=True, shuffle=True)

# %%
## Model
from torchvision.models import resnet18, ResNet18_Weights

## Getting our model and transferring it to the GPU
#model = ResNet18()

model = resnet18(weights=ResNet18_Weights.IMAGENET1K_V1, progress  = True).to(device)
nf = model.fc.in_features
model.fc = nn.Linear(nf,6).to(device)

#define loss function & optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=1e-4)

# %%
wandb.init(
    project="BGMP_HappyWhale",
    name="Kadens_resnet18_1KV1_2", ##update this with your name
    config={"learning rate":0.001, # possibly update
        "architecture": "CNN",
        "dataset": "Species",
        "epochs": 5, "batch_size":48}  # possibly update
) 

batch=0
num_epochs = epochs
train_losses, train_acc_list, val_losses, val_acc_list = [], [], [],[]

for epoch in range(num_epochs):
    # Setting model to "training mode"
    model.train()
    running_loss = 0.0
    correct, total = 0, 0

    # For each batch of data within the loader
    for inputs, labels in train_loader:
        # Send our input images and their labels to the GPU
        inputs, labels = inputs.to(device), labels.to(device)
        # Zero the gradients
        optimizer.zero_grad()
        # Inputting our training images into the model
        # and Predicting the image classification label
        outputs = model(inputs)
        # Figuring out the loss from our predictions
        loss = criterion(outputs, labels)
        # Compute gradients (aka backward pass)
        loss.backward()
        # Update model parameters
        optimizer.step()

        # Adding the loss to our running sum
        # Loss is calculated for each batch within an epoch
        running_loss += loss.item() * inputs.size(0)
        _, predicted = outputs.max(1)
        total += labels.size(0)
        correct += predicted.eq(labels).sum().item()
        batch+=1
        print(f'Epoch [{epoch+1}/{num_epochs}] | Batch #{batch} | Batch Accuracy {(correct/total)*100:.2f}%')


    # Getting metrics for our training pass 
    train_loss = running_loss / len(train_loader.dataset)
    train_acc = 100. * correct / total
    train_losses.append(train_loss)
    train_acc_list.append(train_acc)
    
    # Switching our model to "evaluation mode"
    model.eval()
    running_loss = 0.0
    correct, total = 0, 0
    # Disable gradient calculation b/c we are evalulating the model
    with torch.no_grad():
        # Load in batches of our validation data
        for inputs, labels in val_loader:
            # Send test images and labels to the GPU
            inputs, labels = inputs.to(device), labels.to(device)
            # Predict the image classification label
            outputs = model(inputs)
            _, predicted = outputs.max(1)
            total += labels.size(0)
            # Figuring out how many predicted labels = true labels
            correct += predicted.eq(labels).sum().item()

            # Figuring out the loss from our predictions
            loss = criterion(outputs, labels)
            # Adding the loss to our running sum
            # Loss is calculated for each batch within an epoch
            running_loss += loss.item() * inputs.size(0)
    # Getting our accuracy from our test data
    val_acc = 100. * correct / total
    val_acc_list.append(val_acc)
    # Getting the loss from our test data
    val_loss = running_loss / len(val_loader.dataset)
    val_losses.append(val_loss)
    
    print(f'Epoch [{epoch+1}/{num_epochs}] Train Loss: {train_loss:.4f} | Train Acc: {train_acc:.2f}% | Val Acc: {val_acc:.2f}% | Val Loss: {val_loss:.2f}%')

    # log metrics to wandb
    wandb.log({"validation_accuracy": val_acc, "validation_loss": val_loss, "train_loss":train_loss})

wandb.finish()


"""
Epoch [1/5] Train Loss: 0.3264 | Train Acc: 88.49% | Val Acc: 96.35% | Val Loss: 0.09%
Epoch [2/5] Train Loss: 0.0280 | Train Acc: 99.38% | Val Acc: 95.31% | Val Loss: 0.13%
Epoch [3/5] Train Loss: 0.0209 | Train Acc: 99.38% | Val Acc: 97.14% | Val Loss: 0.06%
Epoch [4/5] Train Loss: 0.0110 | Train Acc: 99.74% | Val Acc: 98.70% | Val Loss: 0.05%
Epoch [5/5] Train Loss: 0.0052 | Train Acc: 99.95% | Val Acc: 98.44% | Val Loss: 0.05%
"""
# Out:
# Finishing previous runs because reinit is set to 'default'.
#  View run <strong style="color:#cdcd00">Kadens_resnet18_1KV1</strong> at: <a href='https://wandb.ai/kbcoulter-university-of-oregon/BGMP_HappyWhale/runs/cndwkbce' target="_blank">https://wandb.ai/kbcoulter-university-of-oregon/BGMP_HappyWhale/runs/cndwkbce</a><br> View project at: <a href='https://wandb.ai/kbcoulter-university-of-oregon/BGMP_HappyWhale' target="_blank">https://wandb.ai/kbcoulter-university-of-oregon/BGMP_HappyWhale</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260226_211300-cndwkbce/logs</code>
# Tracking run with wandb version 0.25.0
# Run data is saved locally in <code>/gpfs/home/kcoulter/HappyWhaleClassifier/wandb/run-20260226_211516-8b0htefa</code>
# Syncing run <strong><a href='https://wandb.ai/kbcoulter-university-of-oregon/BGMP_HappyWhale/runs/8b0htefa' target="_blank">Kadens_resnet18_1KV1_2</a></strong> to <a href='https://wandb.ai/kbcoulter-university-of-oregon/BGMP_HappyWhale' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/kbcoulter-university-of-oregon/BGMP_HappyWhale' target="_blank">https://wandb.ai/kbcoulter-university-of-oregon/BGMP_HappyWhale</a>
#  View run at <a href='https://wandb.ai/kbcoulter-university-of-oregon/BGMP_HappyWhale/runs/8b0htefa' target="_blank">https://wandb.ai/kbcoulter-university-of-oregon/BGMP_HappyWhale/runs/8b0htefa</a>
# Epoch [1/5] | Batch #1 | Batch Accuracy 18.75%
# Epoch [1/5] | Batch #2 | Batch Accuracy 26.04%
# Epoch [1/5] | Batch #3 | Batch Accuracy 33.33%
# Epoch [1/5] | Batch #4 | Batch Accuracy 39.58%
# Epoch [1/5] | Batch #5 | Batch Accuracy 47.08%
# Epoch [1/5] | Batch #6 | Batch Accuracy 53.82%
# Epoch [1/5] | Batch #7 | Batch Accuracy 58.63%
# Epoch [1/5] | Batch #8 | Batch Accuracy 63.54%
# Epoch [1/5] | Batch #9 | Batch Accuracy 66.20%
# Epoch [1/5] | Batch #10 | Batch Accuracy 68.75%
# Epoch [1/5] | Batch #11 | Batch Accuracy 70.45%
# Epoch [1/5] | Batch #12 | Batch Accuracy 72.05%
# Epoch [1/5] | Batch #13 | Batch Accuracy 73.40%
# Epoch [1/5] | Batch #14 | Batch Accuracy 74.70%
# Epoch [1/5] | Batch #15 | Batch Accuracy 75.83%
# Epoch [1/5] | Batch #16 | Batch Accuracy 76.56%
# Epoch [1/5] | Batch #17 | Batch Accuracy 77.45%
# Epoch [1/5] | Batch #18 | Batch Accuracy 78.47%
# Epoch [1/5] | Batch #19 | Batch Accuracy 79.17%
# Epoch [1/5] | Batch #20 | Batch Accuracy 80.10%
# Epoch [1/5] | Batch #21 | Batch Accuracy 80.95%
# Epoch [1/5] | Batch #22 | Batch Accuracy 81.44%
# Epoch [1/5] | Batch #23 | Batch Accuracy 82.16%
# Epoch [1/5] | Batch #24 | Batch Accuracy 82.64%
# Epoch [1/5] | Batch #25 | Batch Accuracy 83.25%
# Epoch [1/5] | Batch #26 | Batch Accuracy 83.89%
# Epoch [1/5] | Batch #27 | Batch Accuracy 84.49%
# Epoch [1/5] | Batch #28 | Batch Accuracy 84.82%
# Epoch [1/5] | Batch #29 | Batch Accuracy 85.13%
# Epoch [1/5] | Batch #30 | Batch Accuracy 85.62%
# Epoch [1/5] | Batch #31 | Batch Accuracy 86.09%
# Epoch [1/5] | Batch #32 | Batch Accuracy 86.52%
# Epoch [1/5] | Batch #33 | Batch Accuracy 86.74%
# Epoch [1/5] | Batch #34 | Batch Accuracy 87.07%
# Epoch [1/5] | Batch #35 | Batch Accuracy 87.38%
# Epoch [1/5] | Batch #36 | Batch Accuracy 87.67%
# Epoch [1/5] | Batch #37 | Batch Accuracy 87.95%
# Epoch [1/5] | Batch #38 | Batch Accuracy 88.10%
# Epoch [1/5] | Batch #39 | Batch Accuracy 88.30%
# Epoch [1/5] | Batch #40 | Batch Accuracy 88.49%
# Epoch [1/5] Train Loss: 0.3264 | Train Acc: 88.49% | Val Acc: 96.35% | Val Loss: 0.09%
# Epoch [2/5] | Batch #41 | Batch Accuracy 100.00%
# Epoch [2/5] | Batch #42 | Batch Accuracy 100.00%
# Epoch [2/5] | Batch #43 | Batch Accuracy 100.00%
# Epoch [2/5] | Batch #44 | Batch Accuracy 98.96%
# Epoch [2/5] | Batch #45 | Batch Accuracy 99.17%
# Epoch [2/5] | Batch #46 | Batch Accuracy 99.31%
# Epoch [2/5] | Batch #47 | Batch Accuracy 99.11%
# Epoch [2/5] | Batch #48 | Batch Accuracy 99.22%
# Epoch [2/5] | Batch #49 | Batch Accuracy 99.07%
# Epoch [2/5] | Batch #50 | Batch Accuracy 99.17%
# Epoch [2/5] | Batch #51 | Batch Accuracy 99.24%
# Epoch [2/5] | Batch #52 | Batch Accuracy 99.31%
# Epoch [2/5] | Batch #53 | Batch Accuracy 99.36%
# Epoch [2/5] | Batch #54 | Batch Accuracy 99.40%
# Epoch [2/5] | Batch #55 | Batch Accuracy 99.44%
# Epoch [2/5] | Batch #56 | Batch Accuracy 99.48%
# Epoch [2/5] | Batch #57 | Batch Accuracy 99.39%
# Epoch [2/5] | Batch #58 | Batch Accuracy 99.42%
# Epoch [2/5] | Batch #59 | Batch Accuracy 99.34%
# Epoch [2/5] | Batch #60 | Batch Accuracy 99.38%
# Epoch [2/5] | Batch #61 | Batch Accuracy 99.40%
# Epoch [2/5] | Batch #62 | Batch Accuracy 99.43%
# Epoch [2/5] | Batch #63 | Batch Accuracy 99.46%
# Epoch [2/5] | Batch #64 | Batch Accuracy 99.48%
# Epoch [2/5] | Batch #65 | Batch Accuracy 99.50%
# Epoch [2/5] | Batch #66 | Batch Accuracy 99.52%
# Epoch [2/5] | Batch #67 | Batch Accuracy 99.46%
# Epoch [2/5] | Batch #68 | Batch Accuracy 99.48%
# Epoch [2/5] | Batch #69 | Batch Accuracy 99.50%
# Epoch [2/5] | Batch #70 | Batch Accuracy 99.51%
# Epoch [2/5] | Batch #71 | Batch Accuracy 99.53%
# Epoch [2/5] | Batch #72 | Batch Accuracy 99.48%
# Epoch [2/5] | Batch #73 | Batch Accuracy 99.49%
# Epoch [2/5] | Batch #74 | Batch Accuracy 99.45%
# Epoch [2/5] | Batch #75 | Batch Accuracy 99.40%
# Epoch [2/5] | Batch #76 | Batch Accuracy 99.42%
# Epoch [2/5] | Batch #77 | Batch Accuracy 99.38%
# Epoch [2/5] | Batch #78 | Batch Accuracy 99.40%
# Epoch [2/5] | Batch #79 | Batch Accuracy 99.41%
# Epoch [2/5] | Batch #80 | Batch Accuracy 99.38%
# Epoch [2/5] Train Loss: 0.0280 | Train Acc: 99.38% | Val Acc: 95.31% | Val Loss: 0.13%
# Epoch [3/5] | Batch #81 | Batch Accuracy 97.92%
# Epoch [3/5] | Batch #82 | Batch Accuracy 97.92%
# Epoch [3/5] | Batch #83 | Batch Accuracy 98.61%
# Epoch [3/5] | Batch #84 | Batch Accuracy 98.96%
# Epoch [3/5] | Batch #85 | Batch Accuracy 98.75%
# Epoch [3/5] | Batch #86 | Batch Accuracy 98.96%
# Epoch [3/5] | Batch #87 | Batch Accuracy 98.51%
# Epoch [3/5] | Batch #88 | Batch Accuracy 98.70%
# Epoch [3/5] | Batch #89 | Batch Accuracy 98.84%
# Epoch [3/5] | Batch #90 | Batch Accuracy 98.96%
# Epoch [3/5] | Batch #91 | Batch Accuracy 98.86%
# Epoch [3/5] | Batch #92 | Batch Accuracy 98.96%
# Epoch [3/5] | Batch #93 | Batch Accuracy 98.88%
# Epoch [3/5] | Batch #94 | Batch Accuracy 98.81%
# Epoch [3/5] | Batch #95 | Batch Accuracy 98.89%
# Epoch [3/5] | Batch #96 | Batch Accuracy 98.96%
# Epoch [3/5] | Batch #97 | Batch Accuracy 99.02%
# Epoch [3/5] | Batch #98 | Batch Accuracy 99.07%
# Epoch [3/5] | Batch #99 | Batch Accuracy 99.12%
# Epoch [3/5] | Batch #100 | Batch Accuracy 99.17%
# Epoch [3/5] | Batch #101 | Batch Accuracy 99.21%
# Epoch [3/5] | Batch #102 | Batch Accuracy 99.24%
# Epoch [3/5] | Batch #103 | Batch Accuracy 99.28%
# Epoch [3/5] | Batch #104 | Batch Accuracy 99.31%
# Epoch [3/5] | Batch #105 | Batch Accuracy 99.33%
# Epoch [3/5] | Batch #106 | Batch Accuracy 99.36%
# Epoch [3/5] | Batch #107 | Batch Accuracy 99.38%
# Epoch [3/5] | Batch #108 | Batch Accuracy 99.33%
# Epoch [3/5] | Batch #109 | Batch Accuracy 99.35%
# Epoch [3/5] | Batch #110 | Batch Accuracy 99.38%
# Epoch [3/5] | Batch #111 | Batch Accuracy 99.40%
# Epoch [3/5] | Batch #112 | Batch Accuracy 99.41%
# Epoch [3/5] | Batch #113 | Batch Accuracy 99.43%
# Epoch [3/5] | Batch #114 | Batch Accuracy 99.45%
# Epoch [3/5] | Batch #115 | Batch Accuracy 99.46%
# Epoch [3/5] | Batch #116 | Batch Accuracy 99.42%
# Epoch [3/5] | Batch #117 | Batch Accuracy 99.32%
# Epoch [3/5] | Batch #118 | Batch Accuracy 99.34%
# Epoch [3/5] | Batch #119 | Batch Accuracy 99.36%
# Epoch [3/5] | Batch #120 | Batch Accuracy 99.38%
# Epoch [3/5] Train Loss: 0.0209 | Train Acc: 99.38% | Val Acc: 97.14% | Val Loss: 0.06%
# Epoch [4/5] | Batch #121 | Batch Accuracy 100.00%
# Epoch [4/5] | Batch #122 | Batch Accuracy 100.00%
# Epoch [4/5] | Batch #123 | Batch Accuracy 100.00%
# Epoch [4/5] | Batch #124 | Batch Accuracy 98.96%
# Epoch [4/5] | Batch #125 | Batch Accuracy 99.17%
# Epoch [4/5] | Batch #126 | Batch Accuracy 99.31%
# Epoch [4/5] | Batch #127 | Batch Accuracy 99.40%
# Epoch [4/5] | Batch #128 | Batch Accuracy 99.48%
# Epoch [4/5] | Batch #129 | Batch Accuracy 99.54%
# Epoch [4/5] | Batch #130 | Batch Accuracy 99.58%
# Epoch [4/5] | Batch #131 | Batch Accuracy 99.62%
# Epoch [4/5] | Batch #132 | Batch Accuracy 99.65%
# Epoch [4/5] | Batch #133 | Batch Accuracy 99.68%
# Epoch [4/5] | Batch #134 | Batch Accuracy 99.70%
# Epoch [4/5] | Batch #135 | Batch Accuracy 99.58%
# Epoch [4/5] | Batch #136 | Batch Accuracy 99.61%
# Epoch [4/5] | Batch #137 | Batch Accuracy 99.63%
# Epoch [4/5] | Batch #138 | Batch Accuracy 99.54%
# Epoch [4/5] | Batch #139 | Batch Accuracy 99.56%
# Epoch [4/5] | Batch #140 | Batch Accuracy 99.58%
# Epoch [4/5] | Batch #141 | Batch Accuracy 99.60%
# Epoch [4/5] | Batch #142 | Batch Accuracy 99.62%
# Epoch [4/5] | Batch #143 | Batch Accuracy 99.64%
# Epoch [4/5] | Batch #144 | Batch Accuracy 99.65%
# Epoch [4/5] | Batch #145 | Batch Accuracy 99.58%
# Epoch [4/5] | Batch #146 | Batch Accuracy 99.60%
# Epoch [4/5] | Batch #147 | Batch Accuracy 99.61%
# Epoch [4/5] | Batch #148 | Batch Accuracy 99.63%
# Epoch [4/5] | Batch #149 | Batch Accuracy 99.64%
# Epoch [4/5] | Batch #150 | Batch Accuracy 99.65%
# Epoch [4/5] | Batch #151 | Batch Accuracy 99.66%
# Epoch [4/5] | Batch #152 | Batch Accuracy 99.67%
# Epoch [4/5] | Batch #153 | Batch Accuracy 99.68%
# Epoch [4/5] | Batch #154 | Batch Accuracy 99.69%
# Epoch [4/5] | Batch #155 | Batch Accuracy 99.70%
# Epoch [4/5] | Batch #156 | Batch Accuracy 99.71%
# Epoch [4/5] | Batch #157 | Batch Accuracy 99.72%
# Epoch [4/5] | Batch #158 | Batch Accuracy 99.73%
# Epoch [4/5] | Batch #159 | Batch Accuracy 99.73%
# Epoch [4/5] | Batch #160 | Batch Accuracy 99.74%
# Epoch [4/5] Train Loss: 0.0110 | Train Acc: 99.74% | Val Acc: 98.70% | Val Loss: 0.05%
# Epoch [5/5] | Batch #161 | Batch Accuracy 100.00%
# Epoch [5/5] | Batch #162 | Batch Accuracy 100.00%
# Epoch [5/5] | Batch #163 | Batch Accuracy 100.00%
# Epoch [5/5] | Batch #164 | Batch Accuracy 100.00%
# Epoch [5/5] | Batch #165 | Batch Accuracy 100.00%
# Epoch [5/5] | Batch #166 | Batch Accuracy 100.00%
# Epoch [5/5] | Batch #167 | Batch Accuracy 100.00%
# Epoch [5/5] | Batch #168 | Batch Accuracy 100.00%
# Epoch [5/5] | Batch #169 | Batch Accuracy 100.00%
# Epoch [5/5] | Batch #170 | Batch Accuracy 100.00%
# Epoch [5/5] | Batch #171 | Batch Accuracy 100.00%
# Epoch [5/5] | Batch #172 | Batch Accuracy 100.00%
# Epoch [5/5] | Batch #173 | Batch Accuracy 99.84%
# Epoch [5/5] | Batch #174 | Batch Accuracy 99.85%
# Epoch [5/5] | Batch #175 | Batch Accuracy 99.86%
# Epoch [5/5] | Batch #176 | Batch Accuracy 99.87%
# Epoch [5/5] | Batch #177 | Batch Accuracy 99.88%
# Epoch [5/5] | Batch #178 | Batch Accuracy 99.88%
# Epoch [5/5] | Batch #179 | Batch Accuracy 99.89%
# Epoch [5/5] | Batch #180 | Batch Accuracy 99.90%
# Epoch [5/5] | Batch #181 | Batch Accuracy 99.90%
# Epoch [5/5] | Batch #182 | Batch Accuracy 99.91%
# Epoch [5/5] | Batch #183 | Batch Accuracy 99.91%
# Epoch [5/5] | Batch #184 | Batch Accuracy 99.91%
# Epoch [5/5] | Batch #185 | Batch Accuracy 99.92%
# Epoch [5/5] | Batch #186 | Batch Accuracy 99.92%
# Epoch [5/5] | Batch #187 | Batch Accuracy 99.92%
# Epoch [5/5] | Batch #188 | Batch Accuracy 99.93%
# Epoch [5/5] | Batch #189 | Batch Accuracy 99.93%
# Epoch [5/5] | Batch #190 | Batch Accuracy 99.93%
# Epoch [5/5] | Batch #191 | Batch Accuracy 99.93%
# Epoch [5/5] | Batch #192 | Batch Accuracy 99.93%
# Epoch [5/5] | Batch #193 | Batch Accuracy 99.94%
# Epoch [5/5] | Batch #194 | Batch Accuracy 99.94%
# Epoch [5/5] | Batch #195 | Batch Accuracy 99.94%
# Epoch [5/5] | Batch #196 | Batch Accuracy 99.94%
# Epoch [5/5] | Batch #197 | Batch Accuracy 99.94%
# Epoch [5/5] | Batch #198 | Batch Accuracy 99.95%
# Epoch [5/5] | Batch #199 | Batch Accuracy 99.95%
# Epoch [5/5] | Batch #200 | Batch Accuracy 99.95%
# Epoch [5/5] Train Loss: 0.0052 | Train Acc: 99.95% | Val Acc: 98.44% | Val Loss: 0.05%
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>train_loss</td><td>█▁▁▁▁</td></tr><tr><td>validation_accuracy</td><td>▃▁▅█▇</td></tr><tr><td>validation_loss</td><td>▄█▂▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>train_loss</td><td>0.00521</td></tr><tr><td>validation_accuracy</td><td>98.4375</td></tr><tr><td>validation_loss</td><td>0.04724</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">Kadens_resnet18_1KV1_2</strong> at: <a href='https://wandb.ai/kbcoulter-university-of-oregon/BGMP_HappyWhale/runs/8b0htefa' target="_blank">https://wandb.ai/kbcoulter-university-of-oregon/BGMP_HappyWhale/runs/8b0htefa</a><br> View project at: <a href='https://wandb.ai/kbcoulter-university-of-oregon/BGMP_HappyWhale' target="_blank">https://wandb.ai/kbcoulter-university-of-oregon/BGMP_HappyWhale</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260226_211516-8b0htefa/logs</code>

# %%
plt.plot(range(epochs), val_acc_list, color="magenta")
plt.xlabel("Epoch number")
plt.ylabel("Validation accuracy")
plt.show()

plt.plot(range(epochs), val_losses, color="purple")
plt.xlabel("Epoch number")
plt.ylabel("Validation loss")
plt.show()

y_pred, y_true = predict(model, test_set)
cm_analysis(y_true, y_pred, "Confusion matrix")
# Out:
# /tmp/ipykernel_2972830/2764316866.py:50: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   annot[i, j] = '%.1f%%\n%d/%d' % (p, c, s)

# %% [markdown]
# <font color='magenta'>Were your changes successful? Do you have ideas why your changes were successful or not?

# %% [markdown]
# These changes were incredibly successful. We see a Training Accurary of 99.95% with Validation Accuracy 98.44%. It seems as if we have nearly solved the overfitting issue. Truthfully, it would be very difficult to obtain better performance than this without optimizing functions, but we can try to shrink this gap in performance further.

# %% [markdown]
# #### Your Model 3 (10 pts)

# %% [markdown]
# <font color='magenta'>Describe your changes to the model training process (either changing something about the model, a hyperparameter, how data was inputted into the model, or another aspect) and why you selected those changes.

# %% [markdown]
# Here, we try to close the small gap in performance between training and validation by adjusting (shrinking) the weight decay to be slightly less agressive. I do not expect that this change or any others would yield a notable improvement, but we try nonetheless.

# %%
batchsize = 48
learning_rate=1.5e-4
epochs=5

train_loader = DataLoader(train_set, batch_size=batchsize, drop_last=True, sampler=train_sampler)
val_loader = DataLoader(val_set, batch_size=batchsize, drop_last=True, shuffle=True)
test_loader = DataLoader(test_set, batch_size=batchsize, drop_last=True, shuffle=True)

# %%
## Model
from torchvision.models import resnet18, ResNet18_Weights

## Getting our model and transferring it to the GPU
#model = ResNet18()

model = resnet18(weights=ResNet18_Weights.IMAGENET1K_V1, progress  = True).to(device)
nf = model.fc.in_features
model.fc = nn.Linear(nf,6).to(device)

#define loss function & optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=5e-5)

# %%
wandb.init(
    project="BGMP_HappyWhale",
    name="Kadens_resnet18_1KV1_3", ##update this with your name
    config={"learning rate":0.001, # possibly update
        "architecture": "CNN",
        "dataset": "Species",
        "epochs": 5, "batch_size":48}  # possibly update
) 

batch=0
num_epochs = epochs
train_losses, train_acc_list, val_losses, val_acc_list = [], [], [],[]

for epoch in range(num_epochs):
    # Setting model to "training mode"
    model.train()
    running_loss = 0.0
    correct, total = 0, 0

    # For each batch of data within the loader
    for inputs, labels in train_loader:
        # Send our input images and their labels to the GPU
        inputs, labels = inputs.to(device), labels.to(device)
        # Zero the gradients
        optimizer.zero_grad()
        # Inputting our training images into the model
        # and Predicting the image classification label
        outputs = model(inputs)
        # Figuring out the loss from our predictions
        loss = criterion(outputs, labels)
        # Compute gradients (aka backward pass)
        loss.backward()
        # Update model parameters
        optimizer.step()

        # Adding the loss to our running sum
        # Loss is calculated for each batch within an epoch
        running_loss += loss.item() * inputs.size(0)
        _, predicted = outputs.max(1)
        total += labels.size(0)
        correct += predicted.eq(labels).sum().item()
        batch+=1
        print(f'Epoch [{epoch+1}/{num_epochs}] | Batch #{batch} | Batch Accuracy {(correct/total)*100:.2f}%')


    # Getting metrics for our training pass 
    train_loss = running_loss / len(train_loader.dataset)
    train_acc = 100. * correct / total
    train_losses.append(train_loss)
    train_acc_list.append(train_acc)
    
    # Switching our model to "evaluation mode"
    model.eval()
    running_loss = 0.0
    correct, total = 0, 0
    # Disable gradient calculation b/c we are evalulating the model
    with torch.no_grad():
        # Load in batches of our validation data
        for inputs, labels in val_loader:
            # Send test images and labels to the GPU
            inputs, labels = inputs.to(device), labels.to(device)
            # Predict the image classification label
            outputs = model(inputs)
            _, predicted = outputs.max(1)
            total += labels.size(0)
            # Figuring out how many predicted labels = true labels
            correct += predicted.eq(labels).sum().item()

            # Figuring out the loss from our predictions
            loss = criterion(outputs, labels)
            # Adding the loss to our running sum
            # Loss is calculated for each batch within an epoch
            running_loss += loss.item() * inputs.size(0)
    # Getting our accuracy from our test data
    val_acc = 100. * correct / total
    val_acc_list.append(val_acc)
    # Getting the loss from our test data
    val_loss = running_loss / len(val_loader.dataset)
    val_losses.append(val_loss)
    
    print(f'Epoch [{epoch+1}/{num_epochs}] Train Loss: {train_loss:.4f} | Train Acc: {train_acc:.2f}% | Val Acc: {val_acc:.2f}% | Val Loss: {val_loss:.2f}%')

    # log metrics to wandb
    wandb.log({"validation_accuracy": val_acc, "validation_loss": val_loss, "train_loss":train_loss})

wandb.finish()

"""
Epoch [1/5] Train Loss: 0.3081 | Train Acc: 90.57% | Val Acc: 97.40% | Val Loss: 0.08%
Epoch [2/5] Train Loss: 0.0220 | Train Acc: 99.53% | Val Acc: 97.40% | Val Loss: 0.06%
Epoch [3/5] Train Loss: 0.0185 | Train Acc: 99.48% | Val Acc: 97.40% | Val Loss: 0.06%
Epoch [4/5] Train Loss: 0.0115 | Train Acc: 99.69% | Val Acc: 98.70% | Val Loss: 0.04%
Epoch [5/5] Train Loss: 0.0043 | Train Acc: 99.95% | Val Acc: 98.44% | Val Loss: 0.04%
"""
# Out:
# wandb: ERROR Failed to detect the name of this notebook. You can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /home/kcoulter/.netrc.
# wandb: Currently logged in as: kbcoulter (BGMP_HappyWhale) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.25.0
# Run data is saved locally in <code>/gpfs/home/kcoulter/HappyWhaleClassifier/wandb/run-20260227_120342-sg916j8l</code>
# Syncing run <strong><a href='https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale/runs/sg916j8l' target="_blank">Kadens_resnet18_1KV1_3</a></strong> to <a href='https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale' target="_blank">https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale</a>
#  View run at <a href='https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale/runs/sg916j8l' target="_blank">https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale/runs/sg916j8l</a>
# Epoch [1/5] | Batch #1 | Batch Accuracy 14.58%
# Epoch [1/5] | Batch #2 | Batch Accuracy 16.67%
# Epoch [1/5] | Batch #3 | Batch Accuracy 25.69%
# Epoch [1/5] | Batch #4 | Batch Accuracy 38.02%
# Epoch [1/5] | Batch #5 | Batch Accuracy 47.50%
# Epoch [1/5] | Batch #6 | Batch Accuracy 53.47%
# Epoch [1/5] | Batch #7 | Batch Accuracy 57.74%
# Epoch [1/5] | Batch #8 | Batch Accuracy 61.20%
# Epoch [1/5] | Batch #9 | Batch Accuracy 64.81%
# Epoch [1/5] | Batch #10 | Batch Accuracy 67.29%
# Epoch [1/5] | Batch #11 | Batch Accuracy 69.13%
# Epoch [1/5] | Batch #12 | Batch Accuracy 70.14%
# Epoch [1/5] | Batch #13 | Batch Accuracy 72.12%
# Epoch [1/5] | Batch #14 | Batch Accuracy 73.36%
# Epoch [1/5] | Batch #15 | Batch Accuracy 74.58%
# Epoch [1/5] | Batch #16 | Batch Accuracy 75.65%
# Epoch [1/5] | Batch #17 | Batch Accuracy 76.84%
# Epoch [1/5] | Batch #18 | Batch Accuracy 78.12%
# Epoch [1/5] | Batch #19 | Batch Accuracy 79.17%
# Epoch [1/5] | Batch #20 | Batch Accuracy 79.90%
# Epoch [1/5] | Batch #21 | Batch Accuracy 80.75%
# Epoch [1/5] | Batch #22 | Batch Accuracy 81.63%
# Epoch [1/5] | Batch #23 | Batch Accuracy 82.34%
# Epoch [1/5] | Batch #24 | Batch Accuracy 82.90%
# Epoch [1/5] | Batch #25 | Batch Accuracy 83.58%
# Epoch [1/5] | Batch #26 | Batch Accuracy 84.21%
# Epoch [1/5] | Batch #27 | Batch Accuracy 84.65%
# Epoch [1/5] | Batch #28 | Batch Accuracy 85.12%
# Epoch [1/5] | Batch #29 | Batch Accuracy 85.63%
# Epoch [1/5] | Batch #30 | Batch Accuracy 85.90%
# Epoch [1/5] | Batch #31 | Batch Accuracy 86.16%
# Epoch [1/5] | Batch #32 | Batch Accuracy 86.59%
# Epoch [1/5] | Batch #33 | Batch Accuracy 86.81%
# Epoch [1/5] | Batch #34 | Batch Accuracy 87.19%
# Epoch [1/5] | Batch #35 | Batch Accuracy 87.50%
# Epoch [1/5] | Batch #36 | Batch Accuracy 87.85%
# Epoch [1/5] | Batch #37 | Batch Accuracy 88.12%
# Epoch [1/5] | Batch #38 | Batch Accuracy 88.38%
# Epoch [1/5] | Batch #39 | Batch Accuracy 88.68%
# Epoch [1/5] | Batch #40 | Batch Accuracy 88.91%
# Epoch [1/5] Train Loss: 0.3261 | Train Acc: 88.91% | Val Acc: 96.35% | Val Loss: 0.08%
# Epoch [2/5] | Batch #41 | Batch Accuracy 100.00%
# Epoch [2/5] | Batch #42 | Batch Accuracy 98.96%
# Epoch [2/5] | Batch #43 | Batch Accuracy 99.31%
# Epoch [2/5] | Batch #44 | Batch Accuracy 99.48%
# Epoch [2/5] | Batch #45 | Batch Accuracy 99.17%
# Epoch [2/5] | Batch #46 | Batch Accuracy 99.31%
# Epoch [2/5] | Batch #47 | Batch Accuracy 99.40%
# Epoch [2/5] | Batch #48 | Batch Accuracy 99.22%
# Epoch [2/5] | Batch #49 | Batch Accuracy 99.07%
# Epoch [2/5] | Batch #50 | Batch Accuracy 99.17%
# Epoch [2/5] | Batch #51 | Batch Accuracy 99.05%
# Epoch [2/5] | Batch #52 | Batch Accuracy 99.13%
# Epoch [2/5] | Batch #53 | Batch Accuracy 99.04%
# Epoch [2/5] | Batch #54 | Batch Accuracy 99.11%
# Epoch [2/5] | Batch #55 | Batch Accuracy 99.17%
# Epoch [2/5] | Batch #56 | Batch Accuracy 99.22%
# Epoch [2/5] | Batch #57 | Batch Accuracy 99.26%
# Epoch [2/5] | Batch #58 | Batch Accuracy 99.31%
# Epoch [2/5] | Batch #59 | Batch Accuracy 99.34%
# Epoch [2/5] | Batch #60 | Batch Accuracy 99.38%
# Epoch [2/5] | Batch #61 | Batch Accuracy 99.01%
# Epoch [2/5] | Batch #62 | Batch Accuracy 99.05%
# Epoch [2/5] | Batch #63 | Batch Accuracy 99.00%
# Epoch [2/5] | Batch #64 | Batch Accuracy 99.05%
# Epoch [2/5] | Batch #65 | Batch Accuracy 99.08%
# Epoch [2/5] | Batch #66 | Batch Accuracy 99.12%
# Epoch [2/5] | Batch #67 | Batch Accuracy 99.15%
# Epoch [2/5] | Batch #68 | Batch Accuracy 99.18%
# Epoch [2/5] | Batch #69 | Batch Accuracy 99.21%
# Epoch [2/5] | Batch #70 | Batch Accuracy 99.24%
# Epoch [2/5] | Batch #71 | Batch Accuracy 99.13%
# Epoch [2/5] | Batch #72 | Batch Accuracy 99.09%
# Epoch [2/5] | Batch #73 | Batch Accuracy 99.12%
# Epoch [2/5] | Batch #74 | Batch Accuracy 99.14%
# Epoch [2/5] | Batch #75 | Batch Accuracy 99.17%
# Epoch [2/5] | Batch #76 | Batch Accuracy 99.19%
# Epoch [2/5] | Batch #77 | Batch Accuracy 99.21%
# Epoch [2/5] | Batch #78 | Batch Accuracy 99.18%
# Epoch [2/5] | Batch #79 | Batch Accuracy 99.20%
# Epoch [2/5] | Batch #80 | Batch Accuracy 99.22%
# Epoch [2/5] Train Loss: 0.0324 | Train Acc: 99.22% | Val Acc: 97.66% | Val Loss: 0.06%
# Epoch [3/5] | Batch #81 | Batch Accuracy 100.00%
# Epoch [3/5] | Batch #82 | Batch Accuracy 100.00%
# Epoch [3/5] | Batch #83 | Batch Accuracy 100.00%
# Epoch [3/5] | Batch #84 | Batch Accuracy 99.48%
# Epoch [3/5] | Batch #85 | Batch Accuracy 99.58%
# Epoch [3/5] | Batch #86 | Batch Accuracy 99.65%
# Epoch [3/5] | Batch #87 | Batch Accuracy 99.70%
# Epoch [3/5] | Batch #88 | Batch Accuracy 99.74%
# Epoch [3/5] | Batch #89 | Batch Accuracy 99.77%
# Epoch [3/5] | Batch #90 | Batch Accuracy 99.79%
# Epoch [3/5] | Batch #91 | Batch Accuracy 99.81%
# Epoch [3/5] | Batch #92 | Batch Accuracy 99.83%
# Epoch [3/5] | Batch #93 | Batch Accuracy 99.84%
# Epoch [3/5] | Batch #94 | Batch Accuracy 99.85%
# Epoch [3/5] | Batch #95 | Batch Accuracy 99.86%
# Epoch [3/5] | Batch #96 | Batch Accuracy 99.87%
# Epoch [3/5] | Batch #97 | Batch Accuracy 99.88%
# Epoch [3/5] | Batch #98 | Batch Accuracy 99.88%
# Epoch [3/5] | Batch #99 | Batch Accuracy 99.78%
# Epoch [3/5] | Batch #100 | Batch Accuracy 99.79%
# Epoch [3/5] | Batch #101 | Batch Accuracy 99.80%
# Epoch [3/5] | Batch #102 | Batch Accuracy 99.81%
# Epoch [3/5] | Batch #103 | Batch Accuracy 99.82%
# Epoch [3/5] | Batch #104 | Batch Accuracy 99.83%
# Epoch [3/5] | Batch #105 | Batch Accuracy 99.83%
# Epoch [3/5] | Batch #106 | Batch Accuracy 99.84%
# Epoch [3/5] | Batch #107 | Batch Accuracy 99.85%
# Epoch [3/5] | Batch #108 | Batch Accuracy 99.70%
# Epoch [3/5] | Batch #109 | Batch Accuracy 99.71%
# Epoch [3/5] | Batch #110 | Batch Accuracy 99.65%
# Epoch [3/5] | Batch #111 | Batch Accuracy 99.66%
# Epoch [3/5] | Batch #112 | Batch Accuracy 99.67%
# Epoch [3/5] | Batch #113 | Batch Accuracy 99.68%
# Epoch [3/5] | Batch #114 | Batch Accuracy 99.69%
# Epoch [3/5] | Batch #115 | Batch Accuracy 99.70%
# Epoch [3/5] | Batch #116 | Batch Accuracy 99.71%
# Epoch [3/5] | Batch #117 | Batch Accuracy 99.72%
# Epoch [3/5] | Batch #118 | Batch Accuracy 99.73%
# Epoch [3/5] | Batch #119 | Batch Accuracy 99.73%
# Epoch [3/5] | Batch #120 | Batch Accuracy 99.64%
# Epoch [3/5] Train Loss: 0.0162 | Train Acc: 99.64% | Val Acc: 98.70% | Val Loss: 0.05%
# Epoch [4/5] | Batch #121 | Batch Accuracy 97.92%
# Epoch [4/5] | Batch #122 | Batch Accuracy 98.96%
# Epoch [4/5] | Batch #123 | Batch Accuracy 98.61%
# Epoch [4/5] | Batch #124 | Batch Accuracy 98.44%
# Epoch [4/5] | Batch #125 | Batch Accuracy 98.75%
# Epoch [4/5] | Batch #126 | Batch Accuracy 98.96%
# Epoch [4/5] | Batch #127 | Batch Accuracy 98.81%
# Epoch [4/5] | Batch #128 | Batch Accuracy 98.96%
# Epoch [4/5] | Batch #129 | Batch Accuracy 99.07%
# Epoch [4/5] | Batch #130 | Batch Accuracy 98.96%
# Epoch [4/5] | Batch #131 | Batch Accuracy 99.05%
# Epoch [4/5] | Batch #132 | Batch Accuracy 99.13%
# Epoch [4/5] | Batch #133 | Batch Accuracy 99.20%
# Epoch [4/5] | Batch #134 | Batch Accuracy 99.26%
# Epoch [4/5] | Batch #135 | Batch Accuracy 99.17%
# Epoch [4/5] | Batch #136 | Batch Accuracy 99.22%
# Epoch [4/5] | Batch #137 | Batch Accuracy 99.14%
# Epoch [4/5] | Batch #138 | Batch Accuracy 99.19%
# Epoch [4/5] | Batch #139 | Batch Accuracy 99.23%
# Epoch [4/5] | Batch #140 | Batch Accuracy 99.27%
# Epoch [4/5] | Batch #141 | Batch Accuracy 99.31%
# Epoch [4/5] | Batch #142 | Batch Accuracy 99.34%
# Epoch [4/5] | Batch #143 | Batch Accuracy 99.28%
# Epoch [4/5] | Batch #144 | Batch Accuracy 99.31%
# Epoch [4/5] | Batch #145 | Batch Accuracy 99.33%
# Epoch [4/5] | Batch #146 | Batch Accuracy 99.36%
# Epoch [4/5] | Batch #147 | Batch Accuracy 99.38%
# Epoch [4/5] | Batch #148 | Batch Accuracy 99.40%
# Epoch [4/5] | Batch #149 | Batch Accuracy 99.43%
# Epoch [4/5] | Batch #150 | Batch Accuracy 99.44%
# Epoch [4/5] | Batch #151 | Batch Accuracy 99.46%
# Epoch [4/5] | Batch #152 | Batch Accuracy 99.48%
# Epoch [4/5] | Batch #153 | Batch Accuracy 99.49%
# Epoch [4/5] | Batch #154 | Batch Accuracy 99.51%
# Epoch [4/5] | Batch #155 | Batch Accuracy 99.52%
# Epoch [4/5] | Batch #156 | Batch Accuracy 99.54%
# Epoch [4/5] | Batch #157 | Batch Accuracy 99.55%
# Epoch [4/5] | Batch #158 | Batch Accuracy 99.56%
# Epoch [4/5] | Batch #159 | Batch Accuracy 99.57%
# Epoch [4/5] | Batch #160 | Batch Accuracy 99.58%
# Epoch [4/5] Train Loss: 0.0150 | Train Acc: 99.58% | Val Acc: 98.70% | Val Loss: 0.03%
# Epoch [5/5] | Batch #161 | Batch Accuracy 100.00%
# Epoch [5/5] | Batch #162 | Batch Accuracy 100.00%
# Epoch [5/5] | Batch #163 | Batch Accuracy 100.00%
# Epoch [5/5] | Batch #164 | Batch Accuracy 100.00%
# Epoch [5/5] | Batch #165 | Batch Accuracy 100.00%
# Epoch [5/5] | Batch #166 | Batch Accuracy 100.00%
# Epoch [5/5] | Batch #167 | Batch Accuracy 100.00%
# Epoch [5/5] | Batch #168 | Batch Accuracy 100.00%
# Epoch [5/5] | Batch #169 | Batch Accuracy 100.00%
# Epoch [5/5] | Batch #170 | Batch Accuracy 100.00%
# Epoch [5/5] | Batch #171 | Batch Accuracy 100.00%
# Epoch [5/5] | Batch #172 | Batch Accuracy 100.00%
# Epoch [5/5] | Batch #173 | Batch Accuracy 100.00%
# Epoch [5/5] | Batch #174 | Batch Accuracy 100.00%
# Epoch [5/5] | Batch #175 | Batch Accuracy 100.00%
# Epoch [5/5] | Batch #176 | Batch Accuracy 100.00%
# Epoch [5/5] | Batch #177 | Batch Accuracy 100.00%
# Epoch [5/5] | Batch #178 | Batch Accuracy 100.00%
# Epoch [5/5] | Batch #179 | Batch Accuracy 100.00%
# Epoch [5/5] | Batch #180 | Batch Accuracy 100.00%
# Epoch [5/5] | Batch #181 | Batch Accuracy 99.90%
# Epoch [5/5] | Batch #182 | Batch Accuracy 99.91%
# Epoch [5/5] | Batch #183 | Batch Accuracy 99.91%
# Epoch [5/5] | Batch #184 | Batch Accuracy 99.91%
# Epoch [5/5] | Batch #185 | Batch Accuracy 99.92%
# Epoch [5/5] | Batch #186 | Batch Accuracy 99.92%
# Epoch [5/5] | Batch #187 | Batch Accuracy 99.92%
# Epoch [5/5] | Batch #188 | Batch Accuracy 99.93%
# Epoch [5/5] | Batch #189 | Batch Accuracy 99.93%
# Epoch [5/5] | Batch #190 | Batch Accuracy 99.93%
# Epoch [5/5] | Batch #191 | Batch Accuracy 99.93%
# Epoch [5/5] | Batch #192 | Batch Accuracy 99.93%
# Epoch [5/5] | Batch #193 | Batch Accuracy 99.94%
# Epoch [5/5] | Batch #194 | Batch Accuracy 99.94%
# Epoch [5/5] | Batch #195 | Batch Accuracy 99.94%
# Epoch [5/5] | Batch #196 | Batch Accuracy 99.94%
# Epoch [5/5] | Batch #197 | Batch Accuracy 99.94%
# Epoch [5/5] | Batch #198 | Batch Accuracy 99.95%
# Epoch [5/5] | Batch #199 | Batch Accuracy 99.95%
# Epoch [5/5] | Batch #200 | Batch Accuracy 99.95%
# Epoch [5/5] Train Loss: 0.0067 | Train Acc: 99.95% | Val Acc: 98.44% | Val Loss: 0.04%
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>train_loss</td><td>█▂▁▁▁</td></tr><tr><td>validation_accuracy</td><td>▁▅██▇</td></tr><tr><td>validation_loss</td><td>█▄▃▁▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>train_loss</td><td>0.00673</td></tr><tr><td>validation_accuracy</td><td>98.4375</td></tr><tr><td>validation_loss</td><td>0.04348</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">Kadens_resnet18_1KV1_3</strong> at: <a href='https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale/runs/sg916j8l' target="_blank">https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale/runs/sg916j8l</a><br> View project at: <a href='https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale' target="_blank">https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale</a><br>Synced 7 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260227_120342-sg916j8l/logs</code>
# '\nEpoch [1/5] Train Loss: 0.3081 | Train Acc: 90.57% | Val Acc: 97.40% | Val Loss: 0.08%\nEpoch [2/5] Train Loss: 0.0220 | Train Acc: 99.53% | Val Acc: 97.40% | Val Loss: 0.06%\nEpoch [3/5] Train Loss: 0.0185 | Train Acc: 99.48% | Val Acc: 97.40% | Val Loss: 0.06%\nEpoch [4/5] Train Loss: 0.0115 | Train Acc: 99.69% | Val Acc: 98.70% | Val Loss: 0.04%\nEpoch [5/5] Train Loss: 0.0043 | Train Acc: 99.95% | Val Acc: 98.44% | Val Loss: 0.04%\n'

# %%
plt.plot(range(epochs), val_acc_list, color="magenta")
plt.xlabel("Epoch number")
plt.ylabel("Validation accuracy")
plt.show()

plt.plot(range(epochs), val_losses, color="purple")
plt.xlabel("Epoch number")
plt.ylabel("Validation loss")
plt.show()

y_pred, y_true = predict(model, test_set)
cm_analysis(y_true, y_pred, "Confusion matrix")
# Out:
# /tmp/ipykernel_2972830/2764316866.py:50: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   annot[i, j] = '%.1f%%\n%d/%d' % (p, c, s)

# %% [markdown]
# <font color='magenta'>Were your changes successful? Do you have ideas why your changes were successful or not?

# %% [markdown]
# My changes here were not successful, we see identical accuracy in training and validation at 99.95% and 98.94%. While I did not expect to see an improvement from 99.95 and 98.94%, I assume that my minimal changes in weight decay were not sufficient to improve training and better already excellent model performance.

# %% [markdown]
# <font color='magenta'>Summarize your 3 steps, their success, and what you learned (5 pts)

# %% [markdown]
# I began by switching to the provided beginning model weights. The early layers of ResNet learn generic features, which generalizes across most image classification tasks. In line with this, we adpoted the prespecified model and weights in the hopes of seeing immediate improvement. This was successful, and we saw an improvement to 97.19% training accuracy and 91.93% validation accuracy. However at this point, we see validation loss spike, and a gap between training and validation, suggesting that we are overfitting.
#
# To account for this, I lowered the learning rate and added a weight decay, serving to make smaller adjustments in training, and increasingly shrink the weights to prevent overfitting as training continued. This yielded a 99.95% training and 98.94% validation accuracy with more stable loss (initial spike followed by decline).
#
# While it would be unlikley to see improvement, I shrunk the weight decay slightly, wondering if a less agressive decay would help the model generalize, suspecting this value may have been too large. However, we see identical performance. This is likely because my change was not large enough in magnitude.

# %% [markdown]
# While I have done similiar finetuning with CNNs for image classification, I have never used weights and biases, so that was a learning experience and something I will keep in mine next time I am collaboratively training a model. I had also never manually built out model architecture. This was great to learn, as I now have a better idea for how you would build new CNN architecture from scratch rather than tweaking pre-designed models.
